# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import glob
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 
import scipy.io as sio

from vehicle_model_variant import Environment
# from vehicle_model_ECMS_2 import Environment_ECMS  
from cell_model import CellModel 
from driver_MDP import Driver_MDP

# %%
driving_cycle_path = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
driving_cycle = sio.loadmat(driving_cycle_path)
driving_cycle = driving_cycle["sch_cycle"][:, 1]
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
driver = Driver_MDP(0.02) 

num_states = 4

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    inputs_batchnorm = layers.BatchNormalization()(inputs)
    
    out = layers.Dense(512, activation="relu")(inputs_batchnorm)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    state_input_batchnorm = layers.BatchNormalization()(state_input)
    
    state_out = layers.Dense(16, activation="relu")(state_input_batchnorm)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_out)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model 
    
    
actor_model = get_actor()

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][-2].numpy()
    j_max = state[0][-1].numpy()

    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
def test_model(cycle, model_path): 
#     test_cycle = driver.get_cycle() 
#     env_ECMS = Environment_ECMS(cell_model, cycle, battery_path, motor_path)
#     history_ECMS = env_ECMS.PMP_calculation(EF)
#     print(history_ECMS)
    
    env_DDPG = Environment(cell_model, cycle, battery_path, motor_path, 10) 
    actor_model.load_weights(model_path)
    
    total_reward = 0 
    state = env_DDPG.reset() 
    while True: 
        tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
        action = policy_epsilon_greedy(tf_state, -1)
        next_state, reward, done = env_DDPG.step(action)
        
        state = next_state 
        total_reward += reward 
        
        if done: 
            break 
        
    SOC_deviation_history = np.sum(np.abs(np.array(env_DDPG.history["SOC"]) - 0.6)) 
    history_DDPG = env_DDPG.history 
    print("******************* Test is start *****************")
#     print(test_cycle)
#     print(history_ECMS["SOC_traj"][-1])
#     print(env_DDPG.fuel_consumption)
    print("total reward = {:.3f}".format(total_reward))
    print("final SOC for DDPG: {:.4f}".format(history_DDPG["SOC"][-1]))
    print("FC for DDPG: {:.4f}".format(env_DDPG.fuel_consumption))
    print("******************* Test is done *****************")
    print("")
    
#     plt.figure(figsize=(10, 6))
#     plt.plot(history_ECMS["SOC_traj"], linewidth=2, label="SOC trajectory for ECMS") 
#     plt.plot(history_DDPG["SOC"], linewidth=2, label="SOC trajectory for DDPG")
    
#     plt.grid() 
#     plt.xlabel("Time[s]", fontsize=14)
#     plt.ylabel("SOC", fontsize=14)
#     plt.legend()
#     plt.savefig("DDPG_PMP_comparison.png")
    return total_reward, history_DDPG

# %%
test_cycles = glob.glob("../data/driving_cycles/test/*.mat")
rewards_one = [] 
actor_one = "./DDPG_reference_trained_one_mass1200/actor_model.h5"
for test_cycle in test_cycles: 
    print(test_cycle)
    driving_cycle = sio.loadmat(test_cycle)
    driving_cycle = driving_cycle["sch_cycle"][:, 1]
    total_reward, _ = test_model(driving_cycle, actor_one)
    rewards_one.append(total_reward)
# Out:
# ../data/driving_cycles/test\00_nedc.mat
# WARNING:tensorflow:Layer batch_normalization is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# C:\Users\ValueCreatorSong\Desktop\Academic\graduate_paper\degradation_model\experiment_essential\generalization_final\vehicle_model_variant.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   del_i = (1 / (2 * r_cha)) * (v_cha - (v_cha ** 2 - 4 * r_cha * p_bat) ** (0.5)) * (p_bat < 0) + (1 / (
# C:\Users\ValueCreatorSong\Desktop\Academic\graduate_paper\degradation_model\experiment_essential\generalization_final\vehicle_model_variant.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   2 * r_dis)) * (v_dis - (v_dis ** 2 - 4 * r_dis * p_bat) ** (0.5)) * (p_bat >= 0)
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -113.127
# final SOC for DDPG: 0.6365
# FC for DDPG: 55.7744
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\cudec_freeway.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -99.168
# final SOC for DDPG: 0.6077
# FC for DDPG: 63.2398
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -43.960
# final SOC for DDPG: 0.5974
# FC for DDPG: 10.8196
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\ny_city_traffic.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -22.022
# final SOC for DDPG: 0.6008
# FC for DDPG: 5.9177
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -54.392
# final SOC for DDPG: 0.6004
# FC for DDPG: 18.5520
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_MOLCity.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -85.736
# final SOC for DDPG: 0.6092
# FC for DDPG: 32.8214
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -47.276
# final SOC for DDPG: 0.5975
# FC for DDPG: 10.7461
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -110.550
# final SOC for DDPG: 0.6000
# FC for DDPG: 20.7516
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -117.697
# final SOC for DDPG: 0.5993
# FC for DDPG: 35.0810
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -126.534
# final SOC for DDPG: 0.5987
# FC for DDPG: 32.9951
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -113.741
# final SOC for DDPG: 0.5988
# FC for DDPG: 32.4556
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -74.757
# final SOC for DDPG: 0.5985
# FC for DDPG: 20.0614
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -106.203
# final SOC for DDPG: 0.5994
# FC for DDPG: 28.7065
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -72.908
# final SOC for DDPG: 0.5997
# FC for DDPG: 19.5292
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -97.949
# final SOC for DDPG: 0.5954
# FC for DDPG: 36.3436
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -86.236
# final SOC for DDPG: 0.5985
# FC for DDPG: 25.5452
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Jumper_Brussels_101_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -105.900
# final SOC for DDPG: 0.5965
# FC for DDPG: 23.7788
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Kangoo_DePost_Brussels_101_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -110.132
# final SOC for DDPG: 0.5966
# FC for DDPG: 26.4861
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\wvucity.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -63.317
# final SOC for DDPG: 0.5984
# FC for DDPG: 14.4590
# ******************* Test is done *****************

# %%
test_cycles = glob.glob("../data/driving_cycles/test/*.mat")
rewards_five = [] 
actor_five = "./DDPG_reference_trained_five_mass1200/actor_model.h5"
for test_cycle in test_cycles: 
    print(test_cycle)
    driving_cycle = sio.loadmat(test_cycle)
    driving_cycle = driving_cycle["sch_cycle"][:, 1]
    total_reward, _ = test_model(driving_cycle, actor_five)
    rewards_five.append(total_reward)
# Out:
# ../data/driving_cycles/test\00_nedc.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -149.067
# final SOC for DDPG: 0.6158
# FC for DDPG: 52.1946
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\cudec_freeway.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -129.441
# final SOC for DDPG: 0.6050
# FC for DDPG: 57.5272
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\ny_city_composite_truck.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -70.163
# final SOC for DDPG: 0.5970
# FC for DDPG: 10.8156
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\ny_city_traffic.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -40.822
# final SOC for DDPG: 0.5980
# FC for DDPG: 5.7778
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_DUBDC.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -76.430
# final SOC for DDPG: 0.5976
# FC for DDPG: 18.0667
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_MOLCity.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -150.254
# final SOC for DDPG: 0.5983
# FC for DDPG: 30.6234
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Antwerp1_May19c.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -93.819
# final SOC for DDPG: 0.5933
# FC for DDPG: 10.9009
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_TMB_Line24N_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -228.255
# final SOC for DDPG: 0.5977
# FC for DDPG: 21.5773
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_VH_Brussels_Empty_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -182.739
# final SOC for DDPG: 0.5967
# FC for DDPG: 36.0583
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_VH_Brussels_Full_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -221.688
# final SOC for DDPG: 0.5939
# FC for DDPG: 33.9343
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_BUS_VH_Brussels_Medium_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -197.596
# final SOC for DDPG: 0.5951
# FC for DDPG: 33.4650
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Jumper_BCN_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -138.137
# final SOC for DDPG: 0.5950
# FC for DDPG: 20.5693
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Jumper_MOL_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -184.668
# final SOC for DDPG: 0.5976
# FC for DDPG: 29.7300
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Octavia_BCN_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -123.120
# final SOC for DDPG: 0.5963
# FC for DDPG: 19.5586
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Octavia_MOL_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -157.332
# final SOC for DDPG: 0.5970
# FC for DDPG: 35.6229
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Decade_Polo_BCN_City1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -115.307
# final SOC for DDPG: 0.5965
# FC for DDPG: 25.3001
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Jumper_Brussels_101_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -213.016
# final SOC for DDPG: 0.5925
# FC for DDPG: 24.7180
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\VITO_RW_Kangoo_DePost_Brussels_101_1.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -219.542
# final SOC for DDPG: 0.5928
# FC for DDPG: 27.6422
# ******************* Test is done *****************
#
# ../data/driving_cycles/test\wvucity.mat
# maximum steps, simulation is done ...
# ******************* Test is start *****************
# total reward = -100.529
# final SOC for DDPG: 0.5974
# FC for DDPG: 14.5654
# ******************* Test is done *****************

# %%
plt.figure(figsize=(8, 8))
plt.plot([-20, -40, -60, -100, -200], [-20, -40, -60, -100, -200], "r", linewidth=4)
plt.scatter(rewards_one, rewards_five)
plt.xlim([-180, -20])
plt.ylim([-180, -20])
plt.grid() 
plt.xlabel("rewards for agent trained 1cycle", fontsize=16)
plt.ylabel("rewards for agent trained 5cycles", fontsize=16)

plt.savefig("generalization_comparison.png")
