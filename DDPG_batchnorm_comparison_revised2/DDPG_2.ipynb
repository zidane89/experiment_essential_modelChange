# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 
import scipy.io as sio

from vehicle_model_DDPG2 import Environment 
from cell_model import CellModel 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
driving_cycle_path = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
driving_cycle = sio.loadmat(driving_cycle_path)
driving_cycle = driving_cycle["sch_cycle"][:, 1]
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
env = Environment(cell_model, driving_cycle, battery_path, motor_path, 10)

num_states = 4

# %%
class OUActionNoise: 
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None): 
        self.theta = theta 
        self.mean = mean 
        self.std_dev = std_deviation 
        self.dt = dt 
        self.x_initial = x_initial 
        self.reset() 
        
    def reset(self): 
        if self.x_initial is not None: 
            self.x_prev = self.x_initial 
        else: 
            self.x_prev = 0 
            
    def __call__(self): 
        x = (
             self.x_prev + self.theta * (self.mean - self.x_prev) * self.dt 
            + self.std_dev * np.sqrt(self.dt) * np.random.normal() 
        )
        self.x_prev = x 
        return x

# %%
class Buffer: 
    def __init__(self, buffer_capacity=100000, batch_size=64):      
        self.buffer_capacity = buffer_capacity 
        self.batch_size = batch_size 
        self.buffer_counter = 0 
        
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, 1))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))
        
    def record(self, obs_tuple):
        index = self.buffer_counter % self.buffer_capacity 

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]
        
        self.buffer_counter += 1 
        
    def learn(self): 
        record_range = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(record_range, self.batch_size)

        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])
        
        with tf.GradientTape() as tape: 
            target_actions = target_actor(next_state_batch)
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions])
            critic_value = critic_model([state_batch, action_batch])
            critic_loss = tf.math.reduce_mean(tf.square(y - critic_value)) 
        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables) 
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )
        
        with tf.GradientTape() as tape: 
            actions = actor_model(state_batch)
            critic_value = critic_model([state_batch, actions])
            actor_loss = - tf.math.reduce_mean(critic_value)
        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables) 
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

# %%
def update_target(tau): 
    new_weights = [] 
    target_variables = target_critic.weights
    for i, variable in enumerate(critic_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_critic.set_weights(new_weights)
    
    new_weights = [] 
    target_variables = target_actor.weights
    for i, variable in enumerate(actor_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_actor.set_weights(new_weights)

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    
    out = layers.Dense(512, activation="relu")(inputs)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    
    state_out = layers.Dense(16, activation="relu")(state_input)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_out)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model

# %%
def policy(state, noise_object): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    sampled_action = tf.squeeze(actor_model(state)) 
    noise = noise_object()
    sampled_action = sampled_action.numpy() + noise 
    legal_action = sampled_action * j_max 
    legal_action = np.clip(legal_action, j_min, j_max)
#     print(j_min, j_max, legal_action, noise)
    return legal_action

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][-2].numpy()
    j_max = state[0][-1].numpy()

    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
std_dev = 0.2 
ou_noise = OUActionNoise(mean=0, std_deviation=0.2)

critic_lr = 0.0005 
actor_lr = 0.00025 
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 200
gamma = 0.95 
tau = 0.001 

MAX_EPSILON = 1 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
DELAY_TRAINING = 3000

# %%
def initialization(reward_factor): 
    actor_model = get_actor() 
    critic_model = get_critic() 

    target_actor = get_actor() 
    target_critic = get_critic() 
    target_actor.set_weights(actor_model.get_weights())
    target_critic.set_weights(critic_model.get_weights())
    
    buffer = Buffer(500000, BATCH_SIZE)
    env = Environment(cell_model, driving_cycle, battery_path, motor_path, reward_factor)
    return actor_model, critic_model, target_actor, target_critic, buffer, env

# %%
def save_weights(actor_model, critic_model, target_actor, target_critic, root): 
    actor_model.save_weights("./{}/actor_model_checkpoint".format(root))
    critic_model.save_weights("./{}/critic_model_checkpoint".format(root))
    target_actor.save_weights("./{}/target_actor_checkpoint".format(root))
    target_critic.save_weights("./{}/target_critic_checkpoint".format(root))
    print("model is saved..")

# %%
print(env.version)

num_trials = 3
reward_factor = 10
results_dict = {} 
for trial in range(num_trials): 
    print()
    print("Trial {}".format(trial))
    
    actor_model, critic_model, target_actor, target_critic, buffer, env = initialization(
        reward_factor
    )
    
    eps = MAX_EPSILON 
    steps = 0
    
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    for ep in range(total_episodes): 
        start = time.time() 
        state = env.reset() 
        episodic_reward = 0 

        while True: 
            tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
            action = policy_epsilon_greedy(tf_state, eps)
    #         print(action)
            next_state, reward, done = env.step(action)
            if done: 
                next_state = [0] * num_states 

            buffer.record((state, action, reward, next_state))
            episodic_reward += reward 

            if steps > DELAY_TRAINING: 
                buffer.learn() 
                update_target(tau)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * steps)

            steps += 1

            if done: 
                break 

            state = next_state 

        elapsed_time = time.time() - start 
        print("elapsed_time: {:.3f}".format(elapsed_time))
        episode_rewards.append(episodic_reward) 
        episode_SOCs.append(env.SOC)
        episode_FCs.append(env.fuel_consumption) 

    #     print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
        SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
        print(
              'Episode: {}'.format(ep + 1),
              "Exploration P: {:.4f}".format(eps),
              'Total reward: {}'.format(episodic_reward), 
              "SOC: {:.4f}".format(env.SOC), 
              "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
              "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
        )
    
#     root = "DDPG1_trial{}".format(trial+1)
#     save_weights(actor_model, critic_model, target_actor, target_critic, root)
    
    results_dict[trial + 1] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs 
    }
# Out:
# 3
#
# Trial 0
# maximum steps, simulation is done ...
# elapsed_time: 14.844
# Episode: 1 Exploration P: 1.0000 Total reward: -5054.976724133867 SOC: 0.9999 Cumulative_SOC_deviation: 486.3844 Fuel Consumption: 191.1329
# maximum steps, simulation is done ...
# elapsed_time: 15.155
# Episode: 2 Exploration P: 1.0000 Total reward: -5020.941058499016 SOC: 0.9993 Cumulative_SOC_deviation: 483.1375 Fuel Consumption: 189.5661
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_12 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 53.385
# Episode: 176 Exploration P: 0.0179 Total reward: -312.41021694877594 SOC: 0.5807 Cumulative_SOC_deviation: 19.8104 Fuel Consumption: 114.3063
# maximum steps, simulation is done ...
# elapsed_time: 53.341
# Episode: 177 Exploration P: 0.0177 Total reward: -369.4532286350278 SOC: 0.5934 Cumulative_SOC_deviation: 25.1901 Fuel Consumption: 117.5523
# maximum steps, simulation is done ...
# elapsed_time: 53.081
# Episode: 178 Exploration P: 0.0175 Total reward: -322.16234985049823 SOC: 0.5950 Cumulative_SOC_deviation: 20.5651 Fuel Consumption: 116.5112
# maximum steps, simulation is done ...
# elapsed_time: 53.648
# Episode: 179 Exploration P: 0.0173 Total reward: -325.5445609087021 SOC: 0.5900 Cumulative_SOC_deviation: 20.8697 Fuel Consumption: 116.8474
# maximum steps, simulation is done ...
# elapsed_time: 53.447
# Episode: 180 Exploration P: 0.0171 Total reward: -335.2157261016625 SOC: 0.5931 Cumulative_SOC_deviation: 21.7963 Fuel Consumption: 117.2528
# maximum steps, simulation is done ...
# elapsed_time: 53.363
# Episode: 181 Exploration P: 0.0169 Total reward: -334.576922933975 SOC: 0.5925 Cumulative_SOC_deviation: 21.6533 Fuel Consumption: 118.0444
# maximum steps, simulation is done ...
# elapsed_time: 53.266
# Episode: 182 Exploration P: 0.0167 Total reward: -340.3422256109893 SOC: 0.5850 Cumulative_SOC_deviation: 22.3008 Fuel Consumption: 117.3345
# maximum steps, simulation is done ...
# elapsed_time: 53.115
# Episode: 183 Exploration P: 0.0165 Total reward: -331.0416890534162 SOC: 0.5932 Cumulative_SOC_deviation: 21.4162 Fuel Consumption: 116.8793
# maximum steps, simulation is done ...
# elapsed_time: 53.351
# Episode: 184 Exploration P: 0.0163 Total reward: -308.8974195780427 SOC: 0.5943 Cumulative_SOC_deviation: 19.2405 Fuel Consumption: 116.4923
# maximum steps, simulation is done ...
# elapsed_time: 53.346
# Episode: 185 Exploration P: 0.0162 Total reward: -311.87259958176577 SOC: 0.5974 Cumulative_SOC_deviation: 19.3836 Fuel Consumption: 118.0370
# maximum steps, simulation is done ...
# elapsed_time: 53.321
# Episode: 186 Exploration P: 0.0160 Total reward: -343.22032668857616 SOC: 0.5937 Cumulative_SOC_deviation: 22.4447 Fuel Consumption: 118.7733
# maximum steps, simulation is done ...
# elapsed_time: 53.379
# Episode: 187 Exploration P: 0.0158 Total reward: -337.1798179063271 SOC: 0.5933 Cumulative_SOC_deviation: 21.8853 Fuel Consumption: 118.3268
# maximum steps, simulation is done ...
# elapsed_time: 53.315
# Episode: 188 Exploration P: 0.0157 Total reward: -293.26192715890403 SOC: 0.5812 Cumulative_SOC_deviation: 17.8715 Fuel Consumption: 114.5469
# maximum steps, simulation is done ...
# elapsed_time: 53.177
# Episode: 189 Exploration P: 0.0155 Total reward: -326.44144334750246 SOC: 0.5928 Cumulative_SOC_deviation: 20.9176 Fuel Consumption: 117.2652
# maximum steps, simulation is done ...
# elapsed_time: 53.385
# Episode: 190 Exploration P: 0.0154 Total reward: -355.0065198033511 SOC: 0.5906 Cumulative_SOC_deviation: 23.7873 Fuel Consumption: 117.1337
# maximum steps, simulation is done ...
# elapsed_time: 53.352
# Episode: 191 Exploration P: 0.0152 Total reward: -317.4488441296502 SOC: 0.5940 Cumulative_SOC_deviation: 20.0622 Fuel Consumption: 116.8269
# maximum steps, simulation is done ...
# elapsed_time: 53.480
# Episode: 192 Exploration P: 0.0151 Total reward: -324.070181865736 SOC: 0.5903 Cumulative_SOC_deviation: 20.7216 Fuel Consumption: 116.8546
# maximum steps, simulation is done ...
# elapsed_time: 53.394
# Episode: 193 Exploration P: 0.0149 Total reward: -361.8505376579091 SOC: 0.5904 Cumulative_SOC_deviation: 24.4584 Fuel Consumption: 117.2663
# maximum steps, simulation is done ...
# elapsed_time: 53.147
# Episode: 194 Exploration P: 0.0148 Total reward: -276.12704219851355 SOC: 0.5980 Cumulative_SOC_deviation: 15.9421 Fuel Consumption: 116.7060
# maximum steps, simulation is done ...
# elapsed_time: 53.267
# Episode: 195 Exploration P: 0.0147 Total reward: -337.9520283705818 SOC: 0.5890 Cumulative_SOC_deviation: 22.1825 Fuel Consumption: 116.1271
# maximum steps, simulation is done ...
# elapsed_time: 53.326
# Episode: 196 Exploration P: 0.0146 Total reward: -383.65847230892587 SOC: 0.5927 Cumulative_SOC_deviation: 26.7863 Fuel Consumption: 115.7958
# maximum steps, simulation is done ...
# elapsed_time: 53.333
# Episode: 197 Exploration P: 0.0144 Total reward: -321.0941799099559 SOC: 0.5956 Cumulative_SOC_deviation: 20.5329 Fuel Consumption: 115.7648
# maximum steps, simulation is done ...
# elapsed_time: 53.541
# Episode: 198 Exploration P: 0.0143 Total reward: -344.5600600865707 SOC: 0.5939 Cumulative_SOC_deviation: 22.8325 Fuel Consumption: 116.2347
# maximum steps, simulation is done ...
# elapsed_time: 53.252
# Episode: 199 Exploration P: 0.0142 Total reward: -343.68263635542274 SOC: 0.5900 Cumulative_SOC_deviation: 22.7216 Fuel Consumption: 116.4669
# maximum steps, simulation is done ...
# elapsed_time: 53.259
# Episode: 200 Exploration P: 0.0141 Total reward: -338.20530387103616 SOC: 0.5877 Cumulative_SOC_deviation: 22.3290 Fuel Consumption: 114.9155
#
# Trial 1
# maximum steps, simulation is done ...
# elapsed_time: 10.131
# Episode: 1 Exploration P: 1.0000 Total reward: -5010.597911065816 SOC: 0.9999 Cumulative_SOC_deviation: 482.4186 Fuel Consumption: 186.4118
# maximum steps, simulation is done ...
# elapsed_time: 10.509
# Episode: 2 Exploration P: 1.0000 Total reward: -5124.564906883935 SOC: 0.9997 Cumulative_SOC_deviation: 493.1236 Fuel Consumption: 193.3284
# WARNING:tensorflow:Layer dense_27 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_30 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_21 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer dense_18 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 47.464
# Episode: 144 Exploration P: 0.0290 Total reward: -260.3946576074796 SOC: 0.5969 Cumulative_SOC_deviation: 14.8192 Fuel Consumption: 112.2024
# maximum steps, simulation is done ...
# elapsed_time: 47.532
# Episode: 145 Exploration P: 0.0285 Total reward: -326.6979167898763 SOC: 0.5671 Cumulative_SOC_deviation: 21.6790 Fuel Consumption: 109.9077
# maximum steps, simulation is done ...
# elapsed_time: 47.280
# Episode: 146 Exploration P: 0.0280 Total reward: -277.78605376999417 SOC: 0.5934 Cumulative_SOC_deviation: 16.7899 Fuel Consumption: 109.8873
# maximum steps, simulation is done ...
# elapsed_time: 47.377
# Episode: 147 Exploration P: 0.0275 Total reward: -298.80398704813746 SOC: 0.5854 Cumulative_SOC_deviation: 19.0321 Fuel Consumption: 108.4825
# maximum steps, simulation is done ...
# elapsed_time: 47.568
# Episode: 148 Exploration P: 0.0270 Total reward: -312.5140806504786 SOC: 0.5819 Cumulative_SOC_deviation: 20.0958 Fuel Consumption: 111.5564
# maximum steps, simulation is done ...
# elapsed_time: 47.485
# Episode: 149 Exploration P: 0.0265 Total reward: -292.9598937109335 SOC: 0.5920 Cumulative_SOC_deviation: 18.3596 Fuel Consumption: 109.3640
# maximum steps, simulation is done ...
# elapsed_time: 47.508
# Episode: 150 Exploration P: 0.0261 Total reward: -331.4783399982093 SOC: 0.5986 Cumulative_SOC_deviation: 21.9178 Fuel Consumption: 112.3002
# maximum steps, simulation is done ...
# elapsed_time: 47.696
# Episode: 151 Exploration P: 0.0257 Total reward: -322.6377819209398 SOC: 0.5852 Cumulative_SOC_deviation: 21.1191 Fuel Consumption: 111.4467
# maximum steps, simulation is done ...
# elapsed_time: 47.492
# Episode: 152 Exploration P: 0.0252 Total reward: -324.9804267068117 SOC: 0.5977 Cumulative_SOC_deviation: 21.1836 Fuel Consumption: 113.1444
# maximum steps, simulation is done ...
# elapsed_time: 47.305
# Episode: 153 Exploration P: 0.0248 Total reward: -315.4420527767713 SOC: 0.5782 Cumulative_SOC_deviation: 20.5117 Fuel Consumption: 110.3247
# maximum steps, simulation is done ...
# elapsed_time: 47.570
# Episode: 154 Exploration P: 0.0244 Total reward: -272.5430107756534 SOC: 0.5950 Cumulative_SOC_deviation: 16.3848 Fuel Consumption: 108.6945
# maximum steps, simulation is done ...
# elapsed_time: 47.494
# Episode: 155 Exploration P: 0.0240 Total reward: -321.4747400971012 SOC: 0.5945 Cumulative_SOC_deviation: 21.1234 Fuel Consumption: 110.2408
# maximum steps, simulation is done ...
# elapsed_time: 47.587
# Episode: 156 Exploration P: 0.0237 Total reward: -262.0976317538635 SOC: 0.5972 Cumulative_SOC_deviation: 14.9577 Fuel Consumption: 112.5207
# maximum steps, simulation is done ...
# elapsed_time: 47.371
# Episode: 157 Exploration P: 0.0233 Total reward: -237.94875886241283 SOC: 0.5856 Cumulative_SOC_deviation: 12.9585 Fuel Consumption: 108.3637
# maximum steps, simulation is done ...
# elapsed_time: 47.526
# maximum steps, simulation is done ...
# elapsed_time: 47.548
# Episode: 173 Exploration P: 0.0186 Total reward: -297.6486796362152 SOC: 0.5928 Cumulative_SOC_deviation: 18.9891 Fuel Consumption: 107.7580
# maximum steps, simulation is done ...
# elapsed_time: 47.768
# Episode: 174 Exploration P: 0.0183 Total reward: -254.90705215923225 SOC: 0.5960 Cumulative_SOC_deviation: 14.6093 Fuel Consumption: 108.8136
# maximum steps, simulation is done ...
# elapsed_time: 47.244
# Episode: 175 Exploration P: 0.0181 Total reward: -304.76164148897385 SOC: 0.5986 Cumulative_SOC_deviation: 19.5806 Fuel Consumption: 108.9554
# maximum steps, simulation is done ...
# elapsed_time: 47.529
# Episode: 176 Exploration P: 0.0179 Total reward: -257.87413075446744 SOC: 0.5982 Cumulative_SOC_deviation: 14.9734 Fuel Consumption: 108.1405
# maximum steps, simulation is done ...
# elapsed_time: 47.622
# Episode: 177 Exploration P: 0.0177 Total reward: -288.0613748277757 SOC: 0.5922 Cumulative_SOC_deviation: 18.0406 Fuel Consumption: 107.6558
# maximum steps, simulation is done ...
# elapsed_time: 47.459
# Episode: 178 Exploration P: 0.0175 Total reward: -314.94236374883235 SOC: 0.5959 Cumulative_SOC_deviation: 20.6684 Fuel Consumption: 108.2584
# maximum steps, simulation is done ...
# elapsed_time: 47.552
# Episode: 179 Exploration P: 0.0173 Total reward: -297.7968900014693 SOC: 0.5870 Cumulative_SOC_deviation: 19.0360 Fuel Consumption: 107.4373
# maximum steps, simulation is done ...
# elapsed_time: 47.617
# Episode: 180 Exploration P: 0.0171 Total reward: -251.91987193636868 SOC: 0.5967 Cumulative_SOC_deviation: 14.4077 Fuel Consumption: 107.8428
# maximum steps, simulation is done ...
# elapsed_time: 47.651
# Episode: 181 Exploration P: 0.0169 Total reward: -246.94313582902097 SOC: 0.5880 Cumulative_SOC_deviation: 13.9853 Fuel Consumption: 107.0901
# maximum steps, simulation is done ...
# elapsed_time: 47.289
# Episode: 182 Exploration P: 0.0167 Total reward: -287.26683013003253 SOC: 0.5891 Cumulative_SOC_deviation: 17.9302 Fuel Consumption: 107.9649
# maximum steps, simulation is done ...
# elapsed_time: 47.513
# Episode: 183 Exploration P: 0.0165 Total reward: -259.30478637028824 SOC: 0.5837 Cumulative_SOC_deviation: 15.1901 Fuel Consumption: 107.4035
# maximum steps, simulation is done ...
# elapsed_time: 47.543
# Episode: 184 Exploration P: 0.0163 Total reward: -372.73317299004026 SOC: 0.5914 Cumulative_SOC_deviation: 26.2009 Fuel Consumption: 110.7243
# maximum steps, simulation is done ...
# elapsed_time: 47.644
# Episode: 185 Exploration P: 0.0162 Total reward: -288.059832762356 SOC: 0.5884 Cumulative_SOC_deviation: 17.9946 Fuel Consumption: 108.1135
# maximum steps, simulation is done ...
# elapsed_time: 47.477
# Episode: 186 Exploration P: 0.0160 Total reward: -265.7957874749819 SOC: 0.5896 Cumulative_SOC_deviation: 15.6964 Fuel Consumption: 108.8321
# maximum steps, simulation is done ...
# elapsed_time: 47.565
# Episode: 187 Exploration P: 0.0158 Total reward: -328.5297437853981 SOC: 0.5962 Cumulative_SOC_deviation: 21.9612 Fuel Consumption: 108.9174
# maximum steps, simulation is done ...
# elapsed_time: 47.634
# Episode: 188 Exploration P: 0.0157 Total reward: -231.23752106229244 SOC: 0.5942 Cumulative_SOC_deviation: 12.3336 Fuel Consumption: 107.9018
# maximum steps, simulation is done ...
# elapsed_time: 47.318
# Episode: 189 Exploration P: 0.0155 Total reward: -297.23477933844623 SOC: 0.5892 Cumulative_SOC_deviation: 18.8567 Fuel Consumption: 108.6680
# maximum steps, simulation is done ...
# elapsed_time: 47.395
# Episode: 190 Exploration P: 0.0154 Total reward: -294.08267080355733 SOC: 0.5909 Cumulative_SOC_deviation: 18.4655 Fuel Consumption: 109.4281
# maximum steps, simulation is done ...
# elapsed_time: 47.516
# Episode: 191 Exploration P: 0.0152 Total reward: -286.0502696746287 SOC: 0.5914 Cumulative_SOC_deviation: 17.7282 Fuel Consumption: 108.7688
# maximum steps, simulation is done ...
# elapsed_time: 47.510
# Episode: 192 Exploration P: 0.0151 Total reward: -294.3154957745814 SOC: 0.5899 Cumulative_SOC_deviation: 18.5549 Fuel Consumption: 108.7662
# maximum steps, simulation is done ...
# elapsed_time: 47.502
# Episode: 193 Exploration P: 0.0149 Total reward: -305.09502986414157 SOC: 0.5838 Cumulative_SOC_deviation: 19.7549 Fuel Consumption: 107.5462
# maximum steps, simulation is done ...
# elapsed_time: 47.616
# Episode: 194 Exploration P: 0.0148 Total reward: -325.0913983410795 SOC: 0.5906 Cumulative_SOC_deviation: 21.5113 Fuel Consumption: 109.9781
# maximum steps, simulation is done ...
# elapsed_time: 47.491
# Episode: 195 Exploration P: 0.0147 Total reward: -291.5147985597462 SOC: 0.5938 Cumulative_SOC_deviation: 18.2968 Fuel Consumption: 108.5470
# maximum steps, simulation is done ...
# elapsed_time: 47.245
# Episode: 196 Exploration P: 0.0146 Total reward: -315.1620794509528 SOC: 0.5863 Cumulative_SOC_deviation: 20.8031 Fuel Consumption: 107.1309
# maximum steps, simulation is done ...
# elapsed_time: 47.867
# Episode: 197 Exploration P: 0.0144 Total reward: -280.80721552265436 SOC: 0.5993 Cumulative_SOC_deviation: 17.2311 Fuel Consumption: 108.4963
# maximum steps, simulation is done ...
# elapsed_time: 47.400
# Episode: 198 Exploration P: 0.0143 Total reward: -287.2133649975392 SOC: 0.5885 Cumulative_SOC_deviation: 17.9386 Fuel Consumption: 107.8272
# maximum steps, simulation is done ...
# elapsed_time: 47.505
# Episode: 199 Exploration P: 0.0142 Total reward: -354.0748735875584 SOC: 0.5852 Cumulative_SOC_deviation: 24.4787 Fuel Consumption: 109.2880
# maximum steps, simulation is done ...
# elapsed_time: 47.325
# Episode: 200 Exploration P: 0.0141 Total reward: -332.51105539299056 SOC: 0.5893 Cumulative_SOC_deviation: 22.2373 Fuel Consumption: 110.1383

# %%
with open("DDPG2_modelChange.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)
