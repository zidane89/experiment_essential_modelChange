# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import glob
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 
import scipy.io as sio

from vehicle_model_variant import Environment 
from cell_model import CellModel 
from driver_MDP import Driver_MDP 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
# env = Environment(cell_model, drving_cycle, battery_path, motor_path, 10)
driver = Driver_MDP(0.02)

num_states = 4

# %%
class OUActionNoise: 
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None): 
        self.theta = theta 
        self.mean = mean 
        self.std_dev = std_deviation 
        self.dt = dt 
        self.x_initial = x_initial 
        self.reset() 
        
    def reset(self): 
        if self.x_initial is not None: 
            self.x_prev = self.x_initial 
        else: 
            self.x_prev = 0 
            
    def __call__(self): 
        x = (
             self.x_prev + self.theta * (self.mean - self.x_prev) * self.dt 
            + self.std_dev * np.sqrt(self.dt) * np.random.normal() 
        )
        self.x_prev = x 
        return x

# %%
class Buffer: 
    def __init__(self, buffer_capacity=100000, batch_size=64):      
        self.buffer_capacity = buffer_capacity 
        self.batch_size = batch_size 
        self.buffer_counter = 0 
        
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, 1))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))
        
    def record(self, obs_tuple):
        index = self.buffer_counter % self.buffer_capacity 

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]
        
        self.buffer_counter += 1 
        
    def learn(self): 
        record_range = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(record_range, self.batch_size)

        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])
        
        with tf.GradientTape() as tape: 
            target_actions = target_actor(next_state_batch)
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions])
            critic_value = critic_model([state_batch, action_batch])
            critic_loss = tf.math.reduce_mean(tf.square(y - critic_value)) 
        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables) 
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )
        
        with tf.GradientTape() as tape: 
            actions = actor_model(state_batch)
            critic_value = critic_model([state_batch, actions])
            actor_loss = - tf.math.reduce_mean(critic_value)
        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables) 
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

# %%
def update_target(tau): 
    new_weights = [] 
    target_variables = target_critic.weights
    for i, variable in enumerate(critic_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_critic.set_weights(new_weights)
    
    new_weights = [] 
    target_variables = target_actor.weights
    for i, variable in enumerate(actor_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_actor.set_weights(new_weights)

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    inputs_batchnorm = layers.BatchNormalization()(inputs)
    
    out = layers.Dense(512, activation="relu")(inputs_batchnorm)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    state_input_batchnorm = layers.BatchNormalization()(state_input)
    
    state_out = layers.Dense(16, activation="relu")(state_input_batchnorm)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_out)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model

# %%
def policy(state, noise_object): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    sampled_action = tf.squeeze(actor_model(state)) 
    noise = noise_object()
    sampled_action = sampled_action.numpy() + noise 
    legal_action = sampled_action * j_max 
    legal_action = np.clip(legal_action, j_min, j_max)
#     print(j_min, j_max, legal_action, noise)
    return legal_action

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][-2].numpy()
    j_max = state[0][-1].numpy()

    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
std_dev = 0.2 
ou_noise = OUActionNoise(mean=0, std_deviation=0.2)

critic_lr = 0.0005 
actor_lr = 0.00025 
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 200
gamma = 0.95 
tau = 0.001 

MAX_EPSILON = 1.0 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
DELAY_TRAINING = 5000

# %%
def initialization(): 
    actor_model = get_actor() 
    critic_model = get_critic() 
    target_actor = get_actor() 
    target_critic = get_critic() 
    target_actor.set_weights(actor_model.get_weights())
    target_critic.set_weights(critic_model.get_weights())
#     actor_model.load_weights("./DDPG1_trial1/actor_model_checkpoint")
#     critic_model.load_weights("./DDPG1_trial1/critic_model_checkpoint")
#     target_actor.load_weights("./DDPG1_trial1/target_actor_checkpoint")
#     target_critic.load_weights("./DDPG1_trial1/target_critic_checkpoint")
    
    buffer = Buffer(500000, BATCH_SIZE)
    return actor_model, critic_model, target_actor, target_critic, buffer

# %%
def save_weights(actor_model, critic_model, target_actor, target_critic, root): 
    if not os.path.exists(root): 
        os.makedirs(root)
        
    actor_model.save_weights("./{}/actor_model.h5".format(root))
    critic_model.save_weights("./{}/critic_model.h5".format(root))
    target_actor.save_weights("./{}/target_actor.h5".format(root))
    target_critic.save_weights("./{}/target_critic.h5".format(root))
    print("model is saved..")

# %%
def initialization_env(driving_path, reward_factor):
    env = Environment(cell_model, driving_path, battery_path, motor_path, reward_factor)
    return env

# %%
def test_agent(actor_model, reward_factor):
    test_cycle = driver.get_cycle() 
    env = initialization_env(test_cycle, reward_factor)
    
    total_reward = 0
    state = env.reset() 
    while True: 
        tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
        action = policy_epsilon_greedy(tf_state, -1)
        next_state, reward, done = env.step(action)
        
        state = next_state 
        total_reward += reward 
        
        if done: 
            break 
        
    SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
    
    print("******************* Test is start *****************")
#     print(test_cycle)
    print('Total reward: {}'.format(total_reward), 
          "SOC: {:.4f}".format(env.SOC), 
          "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
          "Fuel Consumption: {:.4f}".format(env.fuel_consumption))
    print("******************* Test is done *****************")
    print("")
    plt.subplot(1, 2, 1)
    plt.plot(test_cycle)
    plt.subplot(1, 2, 2)
    plt.plot(env.history["Action"])
    plt.show() 
    return env.history

# %%
def update_reward_factor(reward_factor_temp, result_dict, thresh): 
    SOCs = result_dict["SOCs"]
    SOC_at_equilibrium = np.mean(SOCs[-10:])
    if abs(SOC_at_equilibrium - 0.6) < thresh: 
        terminal = True 
        reward_factor = reward_factor_temp 
    else: 
        terminal = False 
        reward_factor = reward_factor_temp + 5 * (0.6 - SOC_at_equilibrium)
    return reward_factor, terminal

# %%
results_dict = {} 
reward_factor_temp = 1.5

driving_cycle_path = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
driving_cycle = sio.loadmat(driving_cycle_path)
driving_cycle = driving_cycle["sch_cycle"][:, 1]
while True: 
    print("")
    print("reward factor = {}".format(reward_factor_temp))
    print("")
    
    actor_model, critic_model, target_actor, target_critic, buffer = initialization()
    
    eps = MAX_EPSILON 
    steps = 0
    
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    episode_test_history = [] 
    episode_num_test = [] 
    for ep in range(total_episodes): 
        env = initialization_env(driving_cycle, reward_factor_temp)
        
        start = time.time() 
        state = env.reset() 
        episodic_reward = 0 
        while True: 
            tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
            action = policy_epsilon_greedy(tf_state, eps)
    #         print(action)
            next_state, reward, done = env.step(action)
            if done: 
                next_state = [0] * num_states 

            buffer.record((state, action, reward, next_state))
            episodic_reward += reward 

            if steps > DELAY_TRAINING: 
                buffer.learn() 
                update_target(tau)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * (steps
                                                                        -DELAY_TRAINING))

            steps += 1

            if done: 
                break 

            state = next_state 

        elapsed_time = time.time() - start 
        print("elapsed_time: {:.3f}".format(elapsed_time))
        episode_rewards.append(episodic_reward) 
        episode_SOCs.append(env.SOC)
        episode_FCs.append(env.fuel_consumption)
        
        SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
        print(
              'Episode: {}'.format(ep + 1),
              "Exploration P: {:.4f}".format(eps),
              'Total reward: {}'.format(episodic_reward), 
              "SOC: {:.4f}".format(env.SOC), 
              "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
              "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
        )
        print("")
        
        if (ep + 1) % 10 == 0: 
#             history = test_agent(actor_model, reward_factor_temp)
            history = env.history 
            episode_test_history.append(history) 
            episode_num_test.append(ep + 1)
            
    root = "cycleOne_reward_factor{}".format(reward_factor_temp)
    save_weights(actor_model, critic_model, target_actor, target_critic, root)
    
    results_dict[reward_factor_temp] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs, 
        "test_history": episode_test_history, 
        "test_episode_num": episode_num_test,
    }
    
    reward_factor_temp, terminal = update_reward_factor(reward_factor_temp, 
                                                        results_dict[reward_factor_temp], 
                                                        0.015) 
    if terminal: 
        break
# Out:
# reward factor = 1.5
#
# maximum steps, simulation is done ...
# elapsed_time: 16.408
# Episode: 1 Exploration P: 1.0000 Total reward: -925.5790850376394 SOC: 0.9994 Cumulative_SOC_deviation: 488.2358 Fuel Consumption: 193.2254
#
# maximum steps, simulation is done ...
# elapsed_time: 16.431
# Episode: 2 Exploration P: 1.0000 Total reward: -921.1534891301686 SOC: 1.0000 Cumulative_SOC_deviation: 487.0446 Fuel Consumption: 190.5865
#
# maximum steps, simulation is done ...
# elapsed_time: 16.776
# Episode: 3 Exploration P: 1.0000 Total reward: -926.2353738718288 SOC: 1.0000 Cumulative_SOC_deviation: 490.2058 Fuel Consumption: 190.9267
#
# WARNING:tensorflow:Layer batch_normalization_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 38.553
# Episode: 4 Exploration P: 0.9903 Total reward: -929.1785440679935 SOC: 0.9994 Cumulative_SOC_deviation: 487.6530 Fuel Consumption: 197.6990
#
# maximum steps, simulation is done ...
# elapsed_time: 84.931
# Episode: 5 Exploration P: 0.9638 Total reward: -879.6747750124113 SOC: 1.0000 Cumulative_SOC_deviation: 463.7765 Fuel Consumption: 184.0101
#
# maximum steps, simulation is done ...
# elapsed_time: 84.473
# Episode: 6 Exploration P: 0.9379 Total reward: -893.944333981935 SOC: 0.9991 Cumulative_SOC_deviation: 474.5952 Fuel Consumption: 182.0516
#
# maximum steps, simulation is done ...
# elapsed_time: 84.326
# Episode: 7 Exploration P: 0.9128 Total reward: -871.8469245396544 SOC: 1.0000 Cumulative_SOC_deviation: 461.5266 Fuel Consumption: 179.5571
#
# maximum steps, simulation is done ...
# elapsed_time: 115.075
# Episode: 8 Exploration P: 0.8883 Total reward: -862.0753310295272 SOC: 1.0000 Cumulative_SOC_deviation: 455.9536 Fuel Consumption: 178.1449
#
# maximum steps, simulation is done ...
# elapsed_time: 112.696
# Episode: 9 Exploration P: 0.8646 Total reward: -871.1270392120844 SOC: 1.0000 Cumulative_SOC_deviation: 464.2971 Fuel Consumption: 174.6814
#
# maximum steps, simulation is done ...
# elapsed_time: 102.867
# Episode: 10 Exploration P: 0.8414 Total reward: -864.465874814652 SOC: 1.0000 Cumulative_SOC_deviation: 463.1205 Fuel Consumption: 169.7852
#
# maximum steps, simulation is done ...
# elapsed_time: 104.284
# Episode: 11 Exploration P: 0.8189 Total reward: -850.0207739254948 SOC: 1.0000 Cumulative_SOC_deviation: 452.8719 Fuel Consumption: 170.7129
#
# maximum steps, simulation is done ...
# elapsed_time: 104.394
# Episode: 12 Exploration P: 0.7970 Total reward: -841.1251482130388 SOC: 1.0000 Cumulative_SOC_deviation: 446.9140 Fuel Consumption: 170.7541
#
# maximum steps, simulation is done ...
# elapsed_time: 100.878
# Episode: 13 Exploration P: 0.7757 Total reward: -768.9426998944683 SOC: 0.9959 Cumulative_SOC_deviation: 406.4959 Fuel Consumption: 159.1989
#
# maximum steps, simulation is done ...
# elapsed_time: 101.421
# Episode: 14 Exploration P: 0.7549 Total reward: -788.4085751482726 SOC: 0.9977 Cumulative_SOC_deviation: 417.1092 Fuel Consumption: 162.7448
#
# maximum steps, simulation is done ...
# elapsed_time: 103.245
# Episode: 15 Exploration P: 0.7347 Total reward: -787.9889766454843 SOC: 0.9937 Cumulative_SOC_deviation: 419.8600 Fuel Consumption: 158.1990
#
# maximum steps, simulation is done ...
# elapsed_time: 102.420
# Episode: 16 Exploration P: 0.7151 Total reward: -724.3708189087631 SOC: 1.0000 Cumulative_SOC_deviation: 378.5817 Fuel Consumption: 156.4982
#
# maximum steps, simulation is done ...
# elapsed_time: 101.466
# Episode: 17 Exploration P: 0.6960 Total reward: -677.6217174130035 SOC: 0.9980 Cumulative_SOC_deviation: 346.3780 Fuel Consumption: 158.0547
#
# maximum steps, simulation is done ...
# elapsed_time: 101.324
# Episode: 18 Exploration P: 0.6774 Total reward: -730.1981813490468 SOC: 1.0000 Cumulative_SOC_deviation: 382.6865 Fuel Consumption: 156.1684
#
# maximum steps, simulation is done ...
# elapsed_time: 92.828
# Episode: 19 Exploration P: 0.6594 Total reward: -647.1599857284544 SOC: 0.9896 Cumulative_SOC_deviation: 329.5474 Fuel Consumption: 152.8389
#
# maximum steps, simulation is done ...
# elapsed_time: 80.631
# Episode: 20 Exploration P: 0.6418 Total reward: -620.3992378485146 SOC: 0.9982 Cumulative_SOC_deviation: 310.9235 Fuel Consumption: 154.0140
#
# maximum steps, simulation is done ...
# elapsed_time: 81.011
# Episode: 21 Exploration P: 0.6247 Total reward: -692.4771167068889 SOC: 0.9845 Cumulative_SOC_deviation: 360.6384 Fuel Consumption: 151.5195
#
# maximum steps, simulation is done ...
# elapsed_time: 80.988
# Episode: 22 Exploration P: 0.6080 Total reward: -597.8939414651387 SOC: 0.9821 Cumulative_SOC_deviation: 297.3837 Fuel Consumption: 151.8184
#
# maximum steps, simulation is done ...
# elapsed_time: 80.752
# Episode: 23 Exploration P: 0.5918 Total reward: -465.6523078014013 SOC: 0.9609 Cumulative_SOC_deviation: 209.5937 Fuel Consumption: 151.2618
#
# maximum steps, simulation is done ...
# elapsed_time: 89.026
# Episode: 24 Exploration P: 0.5761 Total reward: -425.050364903957 SOC: 0.9266 Cumulative_SOC_deviation: 183.1098 Fuel Consumption: 150.3856
#
# maximum steps, simulation is done ...
# elapsed_time: 83.433
# Episode: 25 Exploration P: 0.5607 Total reward: -385.67327185817936 SOC: 0.9306 Cumulative_SOC_deviation: 156.7141 Fuel Consumption: 150.6021
#
# maximum steps, simulation is done ...
# elapsed_time: 84.787
# Episode: 26 Exploration P: 0.5458 Total reward: -432.798996804896 SOC: 0.9377 Cumulative_SOC_deviation: 188.6260 Fuel Consumption: 149.8599
#
# maximum steps, simulation is done ...
# elapsed_time: 85.860
# Episode: 27 Exploration P: 0.5313 Total reward: -334.8814226265661 SOC: 0.9136 Cumulative_SOC_deviation: 123.6363 Fuel Consumption: 149.4270
# maximum steps, simulation is done ...
# elapsed_time: 88.253
# Episode: 28 Exploration P: 0.5172 Total reward: -326.855561305813 SOC: 0.8473 Cumulative_SOC_deviation: 121.1925 Fuel Consumption: 145.0668
#
# maximum steps, simulation is done ...
# elapsed_time: 86.974
# Episode: 29 Exploration P: 0.5034 Total reward: -237.15087385459438 SOC: 0.7472 Cumulative_SOC_deviation: 67.1550 Fuel Consumption: 136.4184
#
# maximum steps, simulation is done ...
# elapsed_time: 87.529
# Episode: 30 Exploration P: 0.4901 Total reward: -249.91533238805408 SOC: 0.6740 Cumulative_SOC_deviation: 78.7089 Fuel Consumption: 131.8520
#
# maximum steps, simulation is done ...
# elapsed_time: 86.114
# Episode: 31 Exploration P: 0.4771 Total reward: -311.80549228784014 SOC: 0.6211 Cumulative_SOC_deviation: 122.0856 Fuel Consumption: 128.6772
#
# maximum steps, simulation is done ...
# elapsed_time: 83.483
# Episode: 32 Exploration P: 0.4644 Total reward: -241.0238952415473 SOC: 0.7261 Cumulative_SOC_deviation: 70.0875 Fuel Consumption: 135.8927
#
# maximum steps, simulation is done ...
# elapsed_time: 86.218
# Episode: 33 Exploration P: 0.4521 Total reward: -361.38875847266576 SOC: 0.5582 Cumulative_SOC_deviation: 158.5839 Fuel Consumption: 123.5129
#
# maximum steps, simulation is done ...
# elapsed_time: 87.308
# Episode: 34 Exploration P: 0.4401 Total reward: -342.1772149798497 SOC: 0.5167 Cumulative_SOC_deviation: 147.6179 Fuel Consumption: 120.7504
#
# maximum steps, simulation is done ...
# elapsed_time: 98.289
# Episode: 35 Exploration P: 0.4285 Total reward: -397.251917465952 SOC: 0.4601 Cumulative_SOC_deviation: 187.6123 Fuel Consumption: 115.8335
#
# maximum steps, simulation is done ...
# elapsed_time: 86.590
# Episode: 36 Exploration P: 0.4171 Total reward: -414.70286744586014 SOC: 0.4759 Cumulative_SOC_deviation: 198.3254 Fuel Consumption: 117.2147
#
# maximum steps, simulation is done ...
# elapsed_time: 88.816
# Episode: 37 Exploration P: 0.4061 Total reward: -482.5650384199059 SOC: 0.3532 Cumulative_SOC_deviation: 249.4149 Fuel Consumption: 108.4427
#
# maximum steps, simulation is done ...
# elapsed_time: 87.579
# Episode: 38 Exploration P: 0.3954 Total reward: -542.4091050163057 SOC: 0.3016 Cumulative_SOC_deviation: 292.2659 Fuel Consumption: 104.0103
#
# maximum steps, simulation is done ...
# elapsed_time: 96.691
# Episode: 39 Exploration P: 0.3849 Total reward: -545.7180916472627 SOC: 0.3108 Cumulative_SOC_deviation: 293.8122 Fuel Consumption: 104.9999
#
# maximum steps, simulation is done ...
# elapsed_time: 86.809
# Episode: 40 Exploration P: 0.3748 Total reward: -491.7941930866254 SOC: 0.3411 Cumulative_SOC_deviation: 256.2342 Fuel Consumption: 107.4428
#
# maximum steps, simulation is done ...
# elapsed_time: 79.621
# Episode: 41 Exploration P: 0.3649 Total reward: -515.4423089010681 SOC: 0.2873 Cumulative_SOC_deviation: 274.9477 Fuel Consumption: 103.0207
#
# maximum steps, simulation is done ...
# elapsed_time: 79.336
# Episode: 42 Exploration P: 0.3553 Total reward: -609.535635994569 SOC: 0.1963 Cumulative_SOC_deviation: 341.4218 Fuel Consumption: 97.4029
#
# maximum steps, simulation is done ...
# elapsed_time: 79.663
# Episode: 43 Exploration P: 0.3459 Total reward: -777.6781373108544 SOC: 0.0928 Cumulative_SOC_deviation: 458.0660 Fuel Consumption: 90.5791
#
# maximum steps, simulation is done ...
# elapsed_time: 80.191
# Episode: 44 Exploration P: 0.3368 Total reward: -647.6173200650021 SOC: 0.1525 Cumulative_SOC_deviation: 369.1529 Fuel Consumption: 93.8879
#
# maximum steps, simulation is done ...
# elapsed_time: 79.481
# Episode: 45 Exploration P: 0.3280 Total reward: -722.1003965065735 SOC: 0.1540 Cumulative_SOC_deviation: 417.6607 Fuel Consumption: 95.6093
#
# maximum steps, simulation is done ...
# elapsed_time: 79.687
# Episode: 46 Exploration P: 0.3194 Total reward: -747.5492483025465 SOC: 0.0551 Cumulative_SOC_deviation: 439.3889 Fuel Consumption: 88.4659
# C:\Users\ValueCreatorSong\Desktop\Academic\graduate_paper\degradation_model\experiment_essential_modelChange\DDPG_adaptive_rewardfactor_final\vehicle_model_variant.py:251: RuntimeWarning: invalid value encountered in double_scalars
#   del_i = (1 / (2 * r_cha)) * (v_cha - (v_cha ** 2 - 4 * r_cha * p_bat) ** (0.5)) * (p_bat < 0) + (1 / (
# maximum steps, simulation is done ...
# elapsed_time: 79.770
# Episode: 47 Exploration P: 0.3110 Total reward: -832.6119354231329 SOC: 0.0492 Cumulative_SOC_deviation: 495.7743 Fuel Consumption: 88.9504
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 72.247
# Episode: 48 Exploration P: 0.3036 Total reward: -1742.3436841159255 SOC: -0.0001 Cumulative_SOC_deviation: 444.8426 Fuel Consumption: 75.9808
#
# battery power is 9851.64969299313(+) but condition is not avail
# elapsed_time: 74.774
# Episode: 49 Exploration P: 0.2961 Total reward: -1798.9029718501974 SOC: -0.0014 Cumulative_SOC_deviation: 480.1742 Fuel Consumption: 79.5446
# C:\Users\ValueCreatorSong\Desktop\Academic\graduate_paper\degradation_model\experiment_essential_modelChange\DDPG_adaptive_rewardfactor_final\vehicle_model_variant.py:252: RuntimeWarning: invalid value encountered in double_scalars
#   2 * r_dis)) * (v_dis - (v_dis ** 2 - 4 * r_dis * p_bat) ** (0.5)) * (p_bat >= 0)
# battery power is 5654.301400547441(+) but condition is not avail
# elapsed_time: 56.742
# Episode: 50 Exploration P: 0.2905 Total reward: -1581.0990693713838 SOC: -0.0006 Cumulative_SOC_deviation: 350.3111 Fuel Consumption: 56.5342
#
# battery power is 5694.218662498944(+) but condition is not avail
# elapsed_time: 52.979
# Episode: 51 Exploration P: 0.2855 Total reward: -1501.8963041552472 SOC: -0.0009 Cumulative_SOC_deviation: 301.8423 Fuel Consumption: 50.0349
#
# battery power is 8257.857718697076(+) but condition is not avail
# elapsed_time: 53.639
# Episode: 52 Exploration P: 0.2804 Total reward: -1483.73599010138 SOC: -0.0010 Cumulative_SOC_deviation: 289.4735 Fuel Consumption: 50.4280
#
# battery power is 6932.917864542715(+) but condition is not avail
# elapsed_time: 74.615
# Episode: 53 Exploration P: 0.2735 Total reward: -1798.1731287841153 SOC: -0.0002 Cumulative_SOC_deviation: 480.0958 Fuel Consumption: 78.9306
#
# battery power is 3661.0084202781763(+) but condition is not avail
# elapsed_time: 48.252
# Episode: 54 Exploration P: 0.2692 Total reward: -1452.922476879998 SOC: -0.0006 Cumulative_SOC_deviation: 273.9859 Fuel Consumption: 42.8453
#
# battery power is 11260.89779661877(+) but condition is not avail
# elapsed_time: 49.801
# Episode: 55 Exploration P: 0.2648 Total reward: -1476.0481306897182 SOC: -0.0009 Cumulative_SOC_deviation: 287.8839 Fuel Consumption: 45.1245
#
# battery power is 3461.802307435887(+) but condition is not avail
# elapsed_time: 48.460
# Episode: 56 Exploration P: 0.2605 Total reward: -1475.650231492696 SOC: -0.0001 Cumulative_SOC_deviation: 288.6620 Fuel Consumption: 43.5582
#
# battery power is 8900.316381108572(+) but condition is not avail
# elapsed_time: 49.838
# Episode: 57 Exploration P: 0.2563 Total reward: -1484.7584302769872 SOC: -0.0018 Cumulative_SOC_deviation: 293.8973 Fuel Consumption: 44.8161
#
# maximum steps, simulation is done ...
# elapsed_time: 79.822
# Episode: 58 Exploration P: 0.2496 Total reward: -622.8398686117393 SOC: 0.5176 Cumulative_SOC_deviation: 332.7569 Fuel Consumption: 123.7045
#
# maximum steps, simulation is done ...
# elapsed_time: 79.687
# Episode: 59 Exploration P: 0.2431 Total reward: -439.42826589309817 SOC: 0.3318 Cumulative_SOC_deviation: 223.4535 Fuel Consumption: 104.2480
#
# maximum steps, simulation is done ...
# elapsed_time: 80.472
# Episode: 60 Exploration P: 0.2368 Total reward: -685.536035318317 SOC: 0.2325 Cumulative_SOC_deviation: 390.7717 Fuel Consumption: 99.3786
#
# maximum steps, simulation is done ...
# elapsed_time: 79.527
# Episode: 61 Exploration P: 0.2307 Total reward: -588.5935722235467 SOC: 0.2302 Cumulative_SOC_deviation: 326.4274 Fuel Consumption: 98.9525
#
# maximum steps, simulation is done ...
# elapsed_time: 79.984
# Episode: 62 Exploration P: 0.2247 Total reward: -785.3023070985735 SOC: 0.2770 Cumulative_SOC_deviation: 454.3171 Fuel Consumption: 103.8266
#
# maximum steps, simulation is done ...
# elapsed_time: 79.662
# Episode: 63 Exploration P: 0.2189 Total reward: -477.27810314731596 SOC: 0.3980 Cumulative_SOC_deviation: 243.3255 Fuel Consumption: 112.2898
#
# maximum steps, simulation is done ...
# elapsed_time: 79.741
# Episode: 64 Exploration P: 0.2132 Total reward: -757.9771804080782 SOC: 0.2605 Cumulative_SOC_deviation: 435.2460 Fuel Consumption: 105.1082
#
# maximum steps, simulation is done ...
# elapsed_time: 102.003
# Episode: 65 Exploration P: 0.2077 Total reward: -755.5816382402957 SOC: 0.2847 Cumulative_SOC_deviation: 434.2519 Fuel Consumption: 104.2038
#
# maximum steps, simulation is done ...
# elapsed_time: 105.695
# Episode: 66 Exploration P: 0.2023 Total reward: -754.4061646809951 SOC: 0.2102 Cumulative_SOC_deviation: 438.6923 Fuel Consumption: 96.3677
#
# maximum steps, simulation is done ...
# elapsed_time: 105.267
# Episode: 67 Exploration P: 0.1971 Total reward: -762.0846085670723 SOC: 0.1977 Cumulative_SOC_deviation: 446.5338 Fuel Consumption: 92.2839
#
# maximum steps, simulation is done ...
# elapsed_time: 105.545
# Episode: 68 Exploration P: 0.1921 Total reward: -743.777080374424 SOC: 0.2636 Cumulative_SOC_deviation: 433.2909 Fuel Consumption: 93.8407
#
# maximum steps, simulation is done ...
# elapsed_time: 105.083
# Episode: 69 Exploration P: 0.1871 Total reward: -716.8804240059361 SOC: 0.2109 Cumulative_SOC_deviation: 417.7025 Fuel Consumption: 90.3267
#
# maximum steps, simulation is done ...
# elapsed_time: 109.182
# Episode: 70 Exploration P: 0.1823 Total reward: -850.0356823957142 SOC: 0.1479 Cumulative_SOC_deviation: 508.0068 Fuel Consumption: 88.0254
#
# maximum steps, simulation is done ...
# elapsed_time: 87.852
# Episode: 71 Exploration P: 0.1777 Total reward: -838.3383591669555 SOC: 0.1128 Cumulative_SOC_deviation: 502.7274 Fuel Consumption: 84.2473
#
# maximum steps, simulation is done ...
# elapsed_time: 83.461
# Episode: 72 Exploration P: 0.1731 Total reward: -764.5360769678091 SOC: 0.1758 Cumulative_SOC_deviation: 450.6674 Fuel Consumption: 88.5349
#
# maximum steps, simulation is done ...
# elapsed_time: 105.908
# Episode: 73 Exploration P: 0.1687 Total reward: -881.2622041993203 SOC: 0.0812 Cumulative_SOC_deviation: 531.4762 Fuel Consumption: 84.0480
#
# maximum steps, simulation is done ...
# elapsed_time: 117.155
# Episode: 74 Exploration P: 0.1644 Total reward: -980.9783434569462 SOC: 0.0196 Cumulative_SOC_deviation: 600.4118 Fuel Consumption: 80.3607
#
# maximum steps, simulation is done ...
# elapsed_time: 120.263
# Episode: 75 Exploration P: 0.1602 Total reward: -762.5160645901741 SOC: 0.0535 Cumulative_SOC_deviation: 455.8443 Fuel Consumption: 78.7497
#
# maximum steps, simulation is done ...
# elapsed_time: 115.880
# Episode: 76 Exploration P: 0.1562 Total reward: -996.3882327301794 SOC: 0.0310 Cumulative_SOC_deviation: 611.0255 Fuel Consumption: 79.8499
#
# maximum steps, simulation is done ...
# elapsed_time: 114.459
# Episode: 77 Exploration P: 0.1522 Total reward: -919.0407431310327 SOC: 0.1570 Cumulative_SOC_deviation: 552.5808 Fuel Consumption: 90.1696
#
# battery power is 243.5531632142222(+) but condition is not avail
# elapsed_time: 116.447
# Episode: 78 Exploration P: 0.1484 Total reward: -1990.659809139227 SOC: -0.0008 Cumulative_SOC_deviation: 609.7159 Fuel Consumption: 77.0248
#
# maximum steps, simulation is done ...
# elapsed_time: 110.466
# Episode: 79 Exploration P: 0.1447 Total reward: -868.149769328766 SOC: 0.1602 Cumulative_SOC_deviation: 521.3517 Fuel Consumption: 86.1223
#
# maximum steps, simulation is done ...
# elapsed_time: 109.286
# Episode: 80 Exploration P: 0.1410 Total reward: -848.6982817584081 SOC: 0.1703 Cumulative_SOC_deviation: 507.9227 Fuel Consumption: 86.8142
#
# battery power is 6354.1125913599235(+) but condition is not avail
# elapsed_time: 89.974
# Episode: 81 Exploration P: 0.1381 Total reward: -1700.316161907765 SOC: -0.0003 Cumulative_SOC_deviation: 427.2686 Fuel Consumption: 60.3626
#
# maximum steps, simulation is done ...
# elapsed_time: 107.512
# Episode: 82 Exploration P: 0.1346 Total reward: -890.3138806505834 SOC: 0.0250 Cumulative_SOC_deviation: 541.6814 Fuel Consumption: 77.7917
#
# maximum steps, simulation is done ...
# elapsed_time: 108.688
# Episode: 83 Exploration P: 0.1313 Total reward: -687.4402534739847 SOC: 0.2741 Cumulative_SOC_deviation: 394.5967 Fuel Consumption: 95.5452
#
# maximum steps, simulation is done ...
# elapsed_time: 106.638
# Episode: 84 Exploration P: 0.1280 Total reward: -677.3431866359058 SOC: 0.2656 Cumulative_SOC_deviation: 389.3179 Fuel Consumption: 93.3663
#
# battery power is 13814.642608335038(+) but condition is not avail
# elapsed_time: 99.362
# Episode: 85 Exploration P: 0.1250 Total reward: -1752.5283523666121 SOC: -0.0003 Cumulative_SOC_deviation: 446.2926 Fuel Consumption: 84.0268
#
# battery power is 2344.2962740988105(+) but condition is not avail
# elapsed_time: 67.080
# Episode: 86 Exploration P: 0.1231 Total reward: -1566.9053442865797 SOC: -0.0004 Cumulative_SOC_deviation: 337.7501 Fuel Consumption: 61.2923
#
# maximum steps, simulation is done ...
# elapsed_time: 108.718
# Episode: 87 Exploration P: 0.1200 Total reward: -953.0872015059895 SOC: 0.2037 Cumulative_SOC_deviation: 572.0661 Fuel Consumption: 94.9880
#
# maximum steps, simulation is done ...
# elapsed_time: 107.247
# Episode: 88 Exploration P: 0.1170 Total reward: -957.6995519015957 SOC: -0.0006 Cumulative_SOC_deviation: 575.0002 Fuel Consumption: 95.1993
# battery power is 6434.207245289934(+) but condition is not avail
# elapsed_time: 93.934
# Episode: 89 Exploration P: 0.1145 Total reward: -1977.5476678509795 SOC: -0.0006 Cumulative_SOC_deviation: 509.0243 Fuel Consumption: 214.9130
#
# maximum steps, simulation is done ...
# elapsed_time: 107.101
# Episode: 90 Exploration P: 0.1117 Total reward: -953.3477615642516 SOC: 0.0659 Cumulative_SOC_deviation: 584.0079 Fuel Consumption: 77.3360
#
# maximum steps, simulation is done ...
# elapsed_time: 106.841
# Episode: 91 Exploration P: 0.1089 Total reward: -1024.5205786727945 SOC: 0.1601 Cumulative_SOC_deviation: 623.2221 Fuel Consumption: 89.6875
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 79.878
# Episode: 92 Exploration P: 0.1069 Total reward: -1688.9285362041926 SOC: -0.0001 Cumulative_SOC_deviation: 414.1606 Fuel Consumption: 68.5887
#
# maximum steps, simulation is done ...
# elapsed_time: 107.698
# Episode: 93 Exploration P: 0.1043 Total reward: -863.1350635681117 SOC: 0.1569 Cumulative_SOC_deviation: 519.0537 Fuel Consumption: 84.5545
#
# maximum steps, simulation is done ...
# elapsed_time: 107.236
# Episode: 94 Exploration P: 0.1017 Total reward: -904.4455303505941 SOC: 0.1614 Cumulative_SOC_deviation: 546.2954 Fuel Consumption: 85.0024
#
# maximum steps, simulation is done ...
# elapsed_time: 106.854
# Episode: 95 Exploration P: 0.0992 Total reward: -879.2143643265368 SOC: 0.1331 Cumulative_SOC_deviation: 529.3291 Fuel Consumption: 85.2207
#
# maximum steps, simulation is done ...
# elapsed_time: 106.953
# Episode: 96 Exploration P: 0.0968 Total reward: -932.7201059102497 SOC: 0.1580 Cumulative_SOC_deviation: 562.0963 Fuel Consumption: 89.5756
#
# maximum steps, simulation is done ...
# elapsed_time: 106.654
# Episode: 97 Exploration P: 0.0945 Total reward: -946.3700766206347 SOC: 0.1213 Cumulative_SOC_deviation: 574.8253 Fuel Consumption: 84.1321
#
# maximum steps, simulation is done ...
# elapsed_time: 106.978
# Episode: 98 Exploration P: 0.0922 Total reward: -955.3201207385991 SOC: 0.1362 Cumulative_SOC_deviation: 582.3464 Fuel Consumption: 81.8006
#
# maximum steps, simulation is done ...
# elapsed_time: 106.946
# Episode: 99 Exploration P: 0.0899 Total reward: -1028.478137646811 SOC: 0.0480 Cumulative_SOC_deviation: 634.3303 Fuel Consumption: 76.9826
#
# maximum steps, simulation is done ...
# elapsed_time: 108.265
# Episode: 100 Exploration P: 0.0878 Total reward: -740.4434776636458 SOC: 0.3707 Cumulative_SOC_deviation: 423.7943 Fuel Consumption: 104.7521
#
# maximum steps, simulation is done ...
# elapsed_time: 107.807
# Episode: 101 Exploration P: 0.0857 Total reward: -724.6728513851798 SOC: 0.1487 Cumulative_SOC_deviation: 420.7329 Fuel Consumption: 93.5736
#
# maximum steps, simulation is done ...
# elapsed_time: 107.774
# Episode: 102 Exploration P: 0.0836 Total reward: -949.3598479652574 SOC: 0.0872 Cumulative_SOC_deviation: 577.5259 Fuel Consumption: 83.0711
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 53.422
# Episode: 103 Exploration P: 0.0826 Total reward: -1403.0006745465384 SOC: -0.0000 Cumulative_SOC_deviation: 248.4658 Fuel Consumption: 31.2028
#
# battery power is 3857.5842170742117(+) but condition is not avail
# elapsed_time: 97.185
# Episode: 104 Exploration P: 0.0808 Total reward: -2269.695662419972 SOC: -0.0009 Cumulative_SOC_deviation: 587.2893 Fuel Consumption: 389.6639
#
# maximum steps, simulation is done ...
# elapsed_time: 106.530
# Episode: 105 Exploration P: 0.0789 Total reward: -903.9059810931228 SOC: 0.1408 Cumulative_SOC_deviation: 545.2414 Fuel Consumption: 86.0439
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 80.577
# Episode: 106 Exploration P: 0.0775 Total reward: -1786.0545492184488 SOC: -0.0001 Cumulative_SOC_deviation: 444.5038 Fuel Consumption: 120.1998
#
# maximum steps, simulation is done ...
# elapsed_time: 106.347
# Episode: 107 Exploration P: 0.0757 Total reward: -914.6994094958525 SOC: 0.1362 Cumulative_SOC_deviation: 551.7509 Fuel Consumption: 87.0731
#
# battery power is 1692.3704071237253(+) but condition is not avail
# elapsed_time: 57.711
# Episode: 108 Exploration P: 0.0747 Total reward: -1591.9294955725804 SOC: -0.0001 Cumulative_SOC_deviation: 307.3001 Fuel Consumption: 131.9730
#
# battery power is 7278.294850105769(+) but condition is not avail
# elapsed_time: 47.126
# Episode: 109 Exploration P: 0.0739 Total reward: -1352.1143238905508 SOC: -0.0003 Cumulative_SOC_deviation: 216.7824 Fuel Consumption: 27.8420
#
# battery power is 9796.513975064627(+) but condition is not avail
# elapsed_time: 51.367
# Episode: 110 Exploration P: 0.0731 Total reward: -1457.0477571686636 SOC: -0.0000 Cumulative_SOC_deviation: 254.2742 Fuel Consumption: 76.5374
#
# battery power is 9344.733175111825(+) but condition is not avail
# elapsed_time: 38.156
# Episode: 111 Exploration P: 0.0725 Total reward: -1244.366904964118 SOC: -0.0006 Cumulative_SOC_deviation: 153.6986 Fuel Consumption: 14.7207
#
# battery power is 7186.469885983898(+) but condition is not avail
# elapsed_time: 45.253
# Episode: 112 Exploration P: 0.0718 Total reward: -1346.4741692321304 SOC: -0.0004 Cumulative_SOC_deviation: 207.9194 Fuel Consumption: 35.4964
#
# maximum steps, simulation is done ...
# elapsed_time: 107.760
# Episode: 113 Exploration P: 0.0701 Total reward: -811.3880733054677 SOC: 0.2844 Cumulative_SOC_deviation: 477.1221 Fuel Consumption: 95.7049
#
# maximum steps, simulation is done ...
# elapsed_time: 107.321
# Episode: 114 Exploration P: 0.0685 Total reward: -519.1262272843095 SOC: 0.7067 Cumulative_SOC_deviation: 257.5294 Fuel Consumption: 132.8322
#
# maximum steps, simulation is done ...
# elapsed_time: 107.526
# Episode: 115 Exploration P: 0.0669 Total reward: -228.09710824221284 SOC: 0.7284 Cumulative_SOC_deviation: 65.8072 Fuel Consumption: 129.3863
#
# maximum steps, simulation is done ...
# elapsed_time: 106.660
# Episode: 116 Exploration P: 0.0653 Total reward: -159.4908229546939 SOC: 0.5537 Cumulative_SOC_deviation: 33.4480 Fuel Consumption: 109.3188
#
# maximum steps, simulation is done ...
# elapsed_time: 106.415
# Episode: 117 Exploration P: 0.0638 Total reward: -378.3147306778632 SOC: 0.3990 Cumulative_SOC_deviation: 177.2766 Fuel Consumption: 112.3999
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 53.598
# Episode: 118 Exploration P: 0.0631 Total reward: -1435.7657288087823 SOC: -0.0001 Cumulative_SOC_deviation: 267.6127 Fuel Consumption: 35.2477
#
# battery power is 6085.950588421585(+) but condition is not avail
# elapsed_time: 74.566
# Episode: 119 Exploration P: 0.0621 Total reward: -1640.9422136241296 SOC: -0.0001 Cumulative_SOC_deviation: 395.4916 Fuel Consumption: 48.6057
#
# battery power is 4658.336557311065(+) but condition is not avail
# elapsed_time: 60.635
# Episode: 120 Exploration P: 0.0613 Total reward: -1521.1229044580095 SOC: -0.0003 Cumulative_SOC_deviation: 307.9868 Fuel Consumption: 60.1367
#
# maximum steps, simulation is done ...
# elapsed_time: 106.815
# Episode: 121 Exploration P: 0.0599 Total reward: -705.3331064529102 SOC: 0.6418 Cumulative_SOC_deviation: 348.9391 Fuel Consumption: 181.9245
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 102.854
# Episode: 122 Exploration P: 0.0586 Total reward: -1995.4397667496885 SOC: -0.0008 Cumulative_SOC_deviation: 607.8386 Fuel Consumption: 84.5840
#
# battery power is 11804.916685647822(+) but condition is not avail
# elapsed_time: 82.149
# Episode: 123 Exploration P: 0.0576 Total reward: -1795.8832061564065 SOC: -0.0000 Cumulative_SOC_deviation: 467.0167 Fuel Consumption: 96.2591
#
# battery power is 4435.179463885262(+) but condition is not avail
# elapsed_time: 79.013
# Episode: 124 Exploration P: 0.0566 Total reward: -1760.2380520637093 SOC: -0.0001 Cumulative_SOC_deviation: 435.9772 Fuel Consumption: 107.1732
#
# maximum steps, simulation is done ...
# elapsed_time: 107.582
# Episode: 125 Exploration P: 0.0554 Total reward: -868.9240896737039 SOC: 0.6379 Cumulative_SOC_deviation: 494.5005 Fuel Consumption: 127.1733
#
# maximum steps, simulation is done ...
# elapsed_time: 106.859
# Episode: 126 Exploration P: 0.0541 Total reward: -288.1871846772226 SOC: 0.6767 Cumulative_SOC_deviation: 107.5965 Fuel Consumption: 126.7924
#
# maximum steps, simulation is done ...
# elapsed_time: 106.797
# Episode: 127 Exploration P: 0.0529 Total reward: -372.6203680816425 SOC: 0.8648 Cumulative_SOC_deviation: 160.4139 Fuel Consumption: 131.9995
# maximum steps, simulation is done ...
# elapsed_time: 106.825
# Episode: 128 Exploration P: 0.0518 Total reward: -1046.7317694538183 SOC: 0.8815 Cumulative_SOC_deviation: 513.0331 Fuel Consumption: 277.1821
#
# maximum steps, simulation is done ...
# elapsed_time: 107.054
# Episode: 129 Exploration P: 0.0506 Total reward: -869.2796071421229 SOC: 0.3112 Cumulative_SOC_deviation: 515.5657 Fuel Consumption: 95.9311
#
# maximum steps, simulation is done ...
# elapsed_time: 106.750
# Episode: 130 Exploration P: 0.0495 Total reward: -578.4133294393876 SOC: 0.2709 Cumulative_SOC_deviation: 324.0633 Fuel Consumption: 92.3183
#
# maximum steps, simulation is done ...
# elapsed_time: 106.936
# Episode: 131 Exploration P: 0.0485 Total reward: -824.3142963735457 SOC: 0.2295 Cumulative_SOC_deviation: 489.3872 Fuel Consumption: 90.2334
#
# maximum steps, simulation is done ...
# elapsed_time: 107.364
# Episode: 132 Exploration P: 0.0474 Total reward: -759.2505406712573 SOC: 0.3225 Cumulative_SOC_deviation: 436.8899 Fuel Consumption: 103.9156
#
# maximum steps, simulation is done ...
# elapsed_time: 107.646
# Episode: 133 Exploration P: 0.0464 Total reward: -328.99732726680185 SOC: 0.6462 Cumulative_SOC_deviation: 140.3295 Fuel Consumption: 118.5031
#
# maximum steps, simulation is done ...
# elapsed_time: 107.421
# Episode: 134 Exploration P: 0.0454 Total reward: -518.5087915065116 SOC: 0.8685 Cumulative_SOC_deviation: 251.5924 Fuel Consumption: 141.1202
#
# maximum steps, simulation is done ...
# elapsed_time: 108.615
# Episode: 135 Exploration P: 0.0445 Total reward: -481.5851324012568 SOC: 0.6303 Cumulative_SOC_deviation: 238.3960 Fuel Consumption: 123.9912
#
# maximum steps, simulation is done ...
# elapsed_time: 107.279
# Episode: 136 Exploration P: 0.0435 Total reward: -495.7655203008616 SOC: 0.4650 Cumulative_SOC_deviation: 253.4315 Fuel Consumption: 115.6182
#
# maximum steps, simulation is done ...
# elapsed_time: 106.625
# Episode: 137 Exploration P: 0.0426 Total reward: -423.676790051617 SOC: 0.4379 Cumulative_SOC_deviation: 212.3754 Fuel Consumption: 105.1138
#
# maximum steps, simulation is done ...
# elapsed_time: 107.121
# Episode: 138 Exploration P: 0.0417 Total reward: -224.79963909094957 SOC: 0.6133 Cumulative_SOC_deviation: 67.9361 Fuel Consumption: 122.8955
#
# maximum steps, simulation is done ...
# elapsed_time: 107.120
# Episode: 139 Exploration P: 0.0409 Total reward: -231.5612725277295 SOC: 0.5724 Cumulative_SOC_deviation: 73.8183 Fuel Consumption: 120.8338
#
# maximum steps, simulation is done ...
# elapsed_time: 107.670
# Episode: 140 Exploration P: 0.0400 Total reward: -212.0978888617155 SOC: 0.6123 Cumulative_SOC_deviation: 59.4493 Fuel Consumption: 122.9240
#
# maximum steps, simulation is done ...
# elapsed_time: 107.398
# Episode: 141 Exploration P: 0.0392 Total reward: -162.12119859664247 SOC: 0.6073 Cumulative_SOC_deviation: 26.1014 Fuel Consumption: 122.9691
#
# maximum steps, simulation is done ...
# elapsed_time: 107.567
# Episode: 142 Exploration P: 0.0384 Total reward: -274.56936376621167 SOC: 0.5984 Cumulative_SOC_deviation: 100.6903 Fuel Consumption: 123.5340
#
# maximum steps, simulation is done ...
# elapsed_time: 106.466
# Episode: 143 Exploration P: 0.0377 Total reward: -349.63053190900143 SOC: 0.3480 Cumulative_SOC_deviation: 164.0596 Fuel Consumption: 103.5412
#
# maximum steps, simulation is done ...
# elapsed_time: 107.026
# Episode: 144 Exploration P: 0.0369 Total reward: -294.58666334091396 SOC: 0.6057 Cumulative_SOC_deviation: 117.4095 Fuel Consumption: 118.4725
#
# maximum steps, simulation is done ...
# elapsed_time: 106.980
# Episode: 145 Exploration P: 0.0362 Total reward: -242.0286810752657 SOC: 0.6307 Cumulative_SOC_deviation: 76.3429 Fuel Consumption: 127.5144
#
# maximum steps, simulation is done ...
# elapsed_time: 107.592
# Episode: 146 Exploration P: 0.0355 Total reward: -534.1669682989095 SOC: 0.7160 Cumulative_SOC_deviation: 265.3754 Fuel Consumption: 136.1039
#
# maximum steps, simulation is done ...
# elapsed_time: 107.620
# Episode: 147 Exploration P: 0.0348 Total reward: -458.34268035910355 SOC: 0.2770 Cumulative_SOC_deviation: 240.9893 Fuel Consumption: 96.8587
#
# maximum steps, simulation is done ...
# elapsed_time: 107.743
# Episode: 148 Exploration P: 0.0341 Total reward: -288.9277581032456 SOC: 0.5214 Cumulative_SOC_deviation: 114.9117 Fuel Consumption: 116.5601
#
# maximum steps, simulation is done ...
# elapsed_time: 107.486
# Episode: 149 Exploration P: 0.0335 Total reward: -217.97817561180395 SOC: 0.5716 Cumulative_SOC_deviation: 64.0976 Fuel Consumption: 121.8318
#
# maximum steps, simulation is done ...
# elapsed_time: 107.057
# Episode: 150 Exploration P: 0.0328 Total reward: -276.5251521061845 SOC: 0.6786 Cumulative_SOC_deviation: 95.8974 Fuel Consumption: 132.6791
#
# maximum steps, simulation is done ...
# elapsed_time: 107.209
# Episode: 151 Exploration P: 0.0322 Total reward: -705.6681041214404 SOC: 0.2661 Cumulative_SOC_deviation: 402.0197 Fuel Consumption: 102.6386
#
# maximum steps, simulation is done ...
# elapsed_time: 106.856
# Episode: 152 Exploration P: 0.0316 Total reward: -539.6552155764889 SOC: 0.5902 Cumulative_SOC_deviation: 274.6775 Fuel Consumption: 127.6389
#
# maximum steps, simulation is done ...
# elapsed_time: 106.941
# Episode: 153 Exploration P: 0.0310 Total reward: -234.09014554511023 SOC: 0.6323 Cumulative_SOC_deviation: 69.6654 Fuel Consumption: 129.5921
#
# maximum steps, simulation is done ...
# elapsed_time: 106.725
# Episode: 154 Exploration P: 0.0305 Total reward: -662.3383713355441 SOC: 0.9988 Cumulative_SOC_deviation: 331.8139 Fuel Consumption: 164.6175
#
# maximum steps, simulation is done ...
# elapsed_time: 106.876
# Episode: 155 Exploration P: 0.0299 Total reward: -1135.1129098998454 SOC: 1.0000 Cumulative_SOC_deviation: 526.3417 Fuel Consumption: 345.6003
#
# maximum steps, simulation is done ...
# elapsed_time: 107.269
# Episode: 156 Exploration P: 0.0294 Total reward: -1136.2961666718722 SOC: 1.0000 Cumulative_SOC_deviation: 526.2402 Fuel Consumption: 346.9359
#
# maximum steps, simulation is done ...
# elapsed_time: 108.261
# Episode: 157 Exploration P: 0.0288 Total reward: -1122.7009126569794 SOC: 0.9912 Cumulative_SOC_deviation: 526.0768 Fuel Consumption: 333.5858
#
# maximum steps, simulation is done ...
# elapsed_time: 107.758
# Episode: 158 Exploration P: 0.0283 Total reward: -1113.8218067860125 SOC: 1.0000 Cumulative_SOC_deviation: 520.2132 Fuel Consumption: 333.5021
#
# maximum steps, simulation is done ...
# elapsed_time: 107.474
# Episode: 159 Exploration P: 0.0278 Total reward: -1121.5511632003318 SOC: 1.0000 Cumulative_SOC_deviation: 526.4836 Fuel Consumption: 331.8257
#
# maximum steps, simulation is done ...
# elapsed_time: 107.259
# Episode: 160 Exploration P: 0.0273 Total reward: -1037.5187927592824 SOC: 0.9912 Cumulative_SOC_deviation: 522.7392 Fuel Consumption: 253.4099
#
# maximum steps, simulation is done ...
# elapsed_time: 106.677
# Episode: 161 Exploration P: 0.0269 Total reward: -873.9049170449541 SOC: 0.7271 Cumulative_SOC_deviation: 468.8936 Fuel Consumption: 170.5645
#
# maximum steps, simulation is done ...
# elapsed_time: 106.886
# Episode: 162 Exploration P: 0.0264 Total reward: -619.809797564795 SOC: 0.8022 Cumulative_SOC_deviation: 319.3681 Fuel Consumption: 140.7576
#
# maximum steps, simulation is done ...
# elapsed_time: 106.699
# Episode: 163 Exploration P: 0.0260 Total reward: -345.9444267384267 SOC: 0.8909 Cumulative_SOC_deviation: 134.8866 Fuel Consumption: 143.6146
#
# maximum steps, simulation is done ...
# elapsed_time: 106.727
# Episode: 164 Exploration P: 0.0255 Total reward: -542.8851132739808 SOC: 0.8743 Cumulative_SOC_deviation: 265.0474 Fuel Consumption: 145.3141
#
# maximum steps, simulation is done ...
# elapsed_time: 107.304
# Episode: 165 Exploration P: 0.0251 Total reward: -725.7710223352963 SOC: 0.9006 Cumulative_SOC_deviation: 387.9447 Fuel Consumption: 143.8540
#
# maximum steps, simulation is done ...
# elapsed_time: 107.473
# Episode: 166 Exploration P: 0.0247 Total reward: -640.7359137746495 SOC: 0.9507 Cumulative_SOC_deviation: 326.5685 Fuel Consumption: 150.8831
#
# maximum steps, simulation is done ...
# elapsed_time: 107.472
# Episode: 167 Exploration P: 0.0243 Total reward: -845.3400247424584 SOC: 0.9366 Cumulative_SOC_deviation: 468.5051 Fuel Consumption: 142.5824
#
# maximum steps, simulation is done ...
# elapsed_time: 107.938
# Episode: 168 Exploration P: 0.0239 Total reward: -795.0663193010288 SOC: 0.8913 Cumulative_SOC_deviation: 436.5015 Fuel Consumption: 140.3141
# maximum steps, simulation is done ...
# elapsed_time: 114.411
# Episode: 169 Exploration P: 0.0235 Total reward: -441.1653582505954 SOC: 0.2261 Cumulative_SOC_deviation: 226.5656 Fuel Consumption: 101.3170
#
# maximum steps, simulation is done ...
# elapsed_time: 108.958
# Episode: 170 Exploration P: 0.0232 Total reward: -442.662367161812 SOC: 0.9106 Cumulative_SOC_deviation: 197.9790 Fuel Consumption: 145.6939
#
# maximum steps, simulation is done ...
# elapsed_time: 110.485
# Episode: 171 Exploration P: 0.0228 Total reward: -643.3758600730906 SOC: 0.8923 Cumulative_SOC_deviation: 333.9602 Fuel Consumption: 142.4356
#
# maximum steps, simulation is done ...
# elapsed_time: 119.330
# Episode: 172 Exploration P: 0.0225 Total reward: -755.9123686894783 SOC: 0.8247 Cumulative_SOC_deviation: 413.0297 Fuel Consumption: 136.3678
#
# maximum steps, simulation is done ...
# elapsed_time: 117.730
# Episode: 173 Exploration P: 0.0221 Total reward: -562.4418780473516 SOC: 0.9258 Cumulative_SOC_deviation: 276.7860 Fuel Consumption: 147.2629
#
# maximum steps, simulation is done ...
# elapsed_time: 109.864
# Episode: 174 Exploration P: 0.0218 Total reward: -732.3047166394072 SOC: 0.9218 Cumulative_SOC_deviation: 391.4798 Fuel Consumption: 145.0850
#
# maximum steps, simulation is done ...
# elapsed_time: 118.501
# Episode: 175 Exploration P: 0.0215 Total reward: -744.2757951629093 SOC: 0.9080 Cumulative_SOC_deviation: 401.3054 Fuel Consumption: 142.3178
#
# maximum steps, simulation is done ...
# elapsed_time: 115.654
# Episode: 176 Exploration P: 0.0212 Total reward: -486.94235746614424 SOC: 0.8881 Cumulative_SOC_deviation: 220.7237 Fuel Consumption: 155.8568
#
# maximum steps, simulation is done ...
# elapsed_time: 114.759
# Episode: 177 Exploration P: 0.0209 Total reward: -722.0088404700418 SOC: 0.8854 Cumulative_SOC_deviation: 387.3456 Fuel Consumption: 140.9905
#
# maximum steps, simulation is done ...
# elapsed_time: 117.466
# Episode: 178 Exploration P: 0.0206 Total reward: -481.279176860157 SOC: 0.3780 Cumulative_SOC_deviation: 247.0637 Fuel Consumption: 110.6836
#
# maximum steps, simulation is done ...
# elapsed_time: 96.452
# Episode: 179 Exploration P: 0.0203 Total reward: -345.91373362005396 SOC: 0.1711 Cumulative_SOC_deviation: 168.1729 Fuel Consumption: 93.6544
#
# maximum steps, simulation is done ...
# elapsed_time: 82.697
# Episode: 180 Exploration P: 0.0200 Total reward: -998.7612762526386 SOC: 0.0656 Cumulative_SOC_deviation: 607.1806 Fuel Consumption: 87.9904
#
# maximum steps, simulation is done ...
# elapsed_time: 79.861
# Episode: 181 Exploration P: 0.0197 Total reward: -1035.9507958218885 SOC: 0.0518 Cumulative_SOC_deviation: 635.1791 Fuel Consumption: 83.1822
#
# maximum steps, simulation is done ...
# elapsed_time: 79.515
# Episode: 182 Exploration P: 0.0195 Total reward: -1011.658448836773 SOC: 0.0578 Cumulative_SOC_deviation: 620.7450 Fuel Consumption: 80.5409
#
# maximum steps, simulation is done ...
# elapsed_time: 81.968
# Episode: 183 Exploration P: 0.0192 Total reward: -1011.7425749646435 SOC: 0.0388 Cumulative_SOC_deviation: 623.8935 Fuel Consumption: 75.9024
#
# battery power is 651.8567835680633(+) but condition is not avail
# elapsed_time: 36.431
# Episode: 184 Exploration P: 0.0191 Total reward: -1363.364405183644 SOC: -0.0003 Cumulative_SOC_deviation: 222.1168 Fuel Consumption: 31.0905
#
# battery power is 257.3109228159683(+) but condition is not avail
# elapsed_time: 37.328
# Episode: 185 Exploration P: 0.0190 Total reward: -1341.3434999988176 SOC: -0.0009 Cumulative_SOC_deviation: 214.1327 Fuel Consumption: 21.0505
#
# maximum steps, simulation is done ...
# elapsed_time: 82.623
# Episode: 186 Exploration P: 0.0188 Total reward: -690.3319533967829 SOC: 0.2803 Cumulative_SOC_deviation: 394.3214 Fuel Consumption: 98.8499
#
# maximum steps, simulation is done ...
# elapsed_time: 81.687
# Episode: 187 Exploration P: 0.0185 Total reward: -931.489101109783 SOC: 0.2934 Cumulative_SOC_deviation: 551.0140 Fuel Consumption: 104.9681
#
# maximum steps, simulation is done ...
# elapsed_time: 85.200
# Episode: 188 Exploration P: 0.0183 Total reward: -541.7410626877037 SOC: 0.3151 Cumulative_SOC_deviation: 291.4169 Fuel Consumption: 104.6156
#
# maximum steps, simulation is done ...
# elapsed_time: 85.213
# Episode: 189 Exploration P: 0.0181 Total reward: -352.97144766811937 SOC: 0.6676 Cumulative_SOC_deviation: 151.8278 Fuel Consumption: 125.2297
#
# maximum steps, simulation is done ...
# elapsed_time: 84.999
# Episode: 190 Exploration P: 0.0178 Total reward: -417.8796454720432 SOC: 0.2225 Cumulative_SOC_deviation: 212.9478 Fuel Consumption: 98.4580
#
# maximum steps, simulation is done ...
# elapsed_time: 83.581
# Episode: 191 Exploration P: 0.0176 Total reward: -821.1246864390745 SOC: 0.1973 Cumulative_SOC_deviation: 482.5631 Fuel Consumption: 97.2801
#
# maximum steps, simulation is done ...
# elapsed_time: 90.483
# Episode: 192 Exploration P: 0.0174 Total reward: -999.7861679764334 SOC: 0.1939 Cumulative_SOC_deviation: 600.6245 Fuel Consumption: 98.8495
#
# battery power is 10580.3234612053(+) but condition is not avail
# elapsed_time: 60.289
# Episode: 193 Exploration P: 0.0173 Total reward: -1552.8707230317316 SOC: -0.0002 Cumulative_SOC_deviation: 293.4706 Fuel Consumption: 113.5661
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 49.783
# Episode: 194 Exploration P: 0.0172 Total reward: -1401.8385075133529 SOC: -0.0003 Cumulative_SOC_deviation: 226.2383 Fuel Consumption: 63.3823
#
# maximum steps, simulation is done ...
# elapsed_time: 105.994
# Episode: 195 Exploration P: 0.0170 Total reward: -944.6080456041453 SOC: 0.2320 Cumulative_SOC_deviation: 561.6902 Fuel Consumption: 102.0728
#
# maximum steps, simulation is done ...
# elapsed_time: 106.670
# Episode: 196 Exploration P: 0.0168 Total reward: -585.4106331813705 SOC: 0.7303 Cumulative_SOC_deviation: 290.2020 Fuel Consumption: 150.1076
#
# maximum steps, simulation is done ...
# elapsed_time: 110.794
# Episode: 197 Exploration P: 0.0167 Total reward: -346.5193366180171 SOC: 0.2777 Cumulative_SOC_deviation: 157.8728 Fuel Consumption: 109.7101
#
# maximum steps, simulation is done ...
# elapsed_time: 119.532
# Episode: 198 Exploration P: 0.0165 Total reward: -983.5279418746081 SOC: 0.1208 Cumulative_SOC_deviation: 594.3226 Fuel Consumption: 92.0440
#
# maximum steps, simulation is done ...
# elapsed_time: 113.718
# Episode: 199 Exploration P: 0.0163 Total reward: -899.4826033974198 SOC: 0.0956 Cumulative_SOC_deviation: 540.7993 Fuel Consumption: 88.2837
#
# maximum steps, simulation is done ...
# elapsed_time: 109.324
# Episode: 200 Exploration P: 0.0161 Total reward: -1018.4391648261337 SOC: 0.0401 Cumulative_SOC_deviation: 620.6187 Fuel Consumption: 87.5111
#
# model is saved..
#
# reward factor = 3.5564358473651065
#
# maximum steps, simulation is done ...
# elapsed_time: 14.910
# Episode: 1 Exploration P: 1.0000 Total reward: -1913.6691451459544 SOC: 0.9990 Cumulative_SOC_deviation: 484.4594 Fuel Consumption: 190.7205
#
# maximum steps, simulation is done ...
# elapsed_time: 16.397
# Episode: 2 Exploration P: 1.0000 Total reward: -1890.8742895952375 SOC: 1.0000 Cumulative_SOC_deviation: 475.9746 Fuel Consumption: 198.1010
#
# maximum steps, simulation is done ...
# elapsed_time: 15.508
# Episode: 3 Exploration P: 1.0000 Total reward: -1895.1921341010207 SOC: 1.0000 Cumulative_SOC_deviation: 479.7567 Fuel Consumption: 188.9682
#
# WARNING:tensorflow:Layer batch_normalization_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_7 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer batch_normalization_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# ...
# elapsed_time: 61.030
# Episode: 122 Exploration P: 0.0484 Total reward: -276.1901777697773 SOC: 0.5717 Cumulative_SOC_deviation: 29.7119 Fuel Consumption: 107.3306
# maximum steps, simulation is done ...
# elapsed_time: 61.082
# Episode: 123 Exploration P: 0.0473 Total reward: -202.87243968709274 SOC: 0.5931 Cumulative_SOC_deviation: 16.4398 Fuel Consumption: 109.4416
#
# maximum steps, simulation is done ...
# elapsed_time: 60.832
# Episode: 124 Exploration P: 0.0463 Total reward: -230.19528896837485 SOC: 0.5736 Cumulative_SOC_deviation: 21.6478 Fuel Consumption: 107.1660
#
# maximum steps, simulation is done ...
# elapsed_time: 60.724
# Episode: 125 Exploration P: 0.0453 Total reward: -259.730127487612 SOC: 0.5773 Cumulative_SOC_deviation: 26.6781 Fuel Consumption: 108.1129
#
# maximum steps, simulation is done ...
# elapsed_time: 60.955
# Episode: 126 Exploration P: 0.0444 Total reward: -303.4805870253835 SOC: 0.5640 Cumulative_SOC_deviation: 34.4645 Fuel Consumption: 107.6110
#
# maximum steps, simulation is done ...
# elapsed_time: 61.166
# Episode: 127 Exploration P: 0.0435 Total reward: -215.15697617322806 SOC: 0.5979 Cumulative_SOC_deviation: 18.3924 Fuel Consumption: 110.6291
#
# maximum steps, simulation is done ...
# elapsed_time: 61.262
# Episode: 128 Exploration P: 0.0426 Total reward: -192.23378461541154 SOC: 0.5989 Cumulative_SOC_deviation: 14.5849 Fuel Consumption: 109.3445
#
# maximum steps, simulation is done ...
# elapsed_time: 60.831
# Episode: 129 Exploration P: 0.0417 Total reward: -183.3552244201906 SOC: 0.5928 Cumulative_SOC_deviation: 12.8756 Fuel Consumption: 110.1802
#
# maximum steps, simulation is done ...
# elapsed_time: 60.558
# Episode: 130 Exploration P: 0.0408 Total reward: -158.63085041209533 SOC: 0.5972 Cumulative_SOC_deviation: 8.8223 Fuel Consumption: 108.4919
#
# maximum steps, simulation is done ...
# elapsed_time: 61.217
# Episode: 131 Exploration P: 0.0400 Total reward: -183.16573310155417 SOC: 0.5950 Cumulative_SOC_deviation: 12.9899 Fuel Consumption: 109.3413
#
# maximum steps, simulation is done ...
# elapsed_time: 61.387
# Episode: 132 Exploration P: 0.0392 Total reward: -150.13707015743603 SOC: 0.5936 Cumulative_SOC_deviation: 7.2372 Fuel Consumption: 109.0066
#
# maximum steps, simulation is done ...
# elapsed_time: 61.156
# Episode: 133 Exploration P: 0.0384 Total reward: -141.0990089902698 SOC: 0.5964 Cumulative_SOC_deviation: 5.7204 Fuel Consumption: 108.5887
#
# maximum steps, simulation is done ...
# elapsed_time: 60.921
# Episode: 134 Exploration P: 0.0376 Total reward: -183.72646354841334 SOC: 0.5953 Cumulative_SOC_deviation: 13.3864 Fuel Consumption: 107.6487
#
# maximum steps, simulation is done ...
# elapsed_time: 61.571
# Episode: 135 Exploration P: 0.0369 Total reward: -170.74823810220045 SOC: 0.5974 Cumulative_SOC_deviation: 10.9463 Fuel Consumption: 108.5382
#
# maximum steps, simulation is done ...
# elapsed_time: 61.468
# Episode: 136 Exploration P: 0.0361 Total reward: -138.4068315464372 SOC: 0.5959 Cumulative_SOC_deviation: 5.4198 Fuel Consumption: 107.6051
#
# maximum steps, simulation is done ...
# elapsed_time: 61.026
# Episode: 137 Exploration P: 0.0354 Total reward: -151.9567723847648 SOC: 0.5980 Cumulative_SOC_deviation: 7.6963 Fuel Consumption: 108.2172
#
# maximum steps, simulation is done ...
# elapsed_time: 60.910
# Episode: 138 Exploration P: 0.0347 Total reward: -149.45517106779744 SOC: 0.5929 Cumulative_SOC_deviation: 7.4032 Fuel Consumption: 107.3811
#
# maximum steps, simulation is done ...
# elapsed_time: 61.082
# Episode: 139 Exploration P: 0.0341 Total reward: -181.91621765622094 SOC: 0.5959 Cumulative_SOC_deviation: 13.0582 Fuel Consumption: 107.7039
#
# maximum steps, simulation is done ...
# elapsed_time: 60.859
# Episode: 140 Exploration P: 0.0334 Total reward: -179.50939279936307 SOC: 0.5956 Cumulative_SOC_deviation: 12.6557 Fuel Consumption: 107.5845
#
# maximum steps, simulation is done ...
# elapsed_time: 61.286
# Episode: 141 Exploration P: 0.0328 Total reward: -159.21418828445354 SOC: 0.5929 Cumulative_SOC_deviation: 9.0875 Fuel Consumption: 107.5680
#
# maximum steps, simulation is done ...
# elapsed_time: 61.484
# Episode: 142 Exploration P: 0.0322 Total reward: -182.2417201038347 SOC: 0.5920 Cumulative_SOC_deviation: 13.1103 Fuel Consumption: 107.7331
#
# maximum steps, simulation is done ...
# elapsed_time: 60.900
# Episode: 143 Exploration P: 0.0316 Total reward: -156.89685992632263 SOC: 0.5949 Cumulative_SOC_deviation: 8.6831 Fuel Consumption: 107.5486
#
# maximum steps, simulation is done ...
# elapsed_time: 60.867
# Episode: 144 Exploration P: 0.0310 Total reward: -154.36367644144755 SOC: 0.5967 Cumulative_SOC_deviation: 8.2048 Fuel Consumption: 107.7342
#
# maximum steps, simulation is done ...
# elapsed_time: 60.908
# Episode: 145 Exploration P: 0.0304 Total reward: -156.77309186757662 SOC: 0.5918 Cumulative_SOC_deviation: 8.6934 Fuel Consumption: 107.3665
#
# maximum steps, simulation is done ...
# elapsed_time: 61.028
# Episode: 146 Exploration P: 0.0299 Total reward: -147.0504562503833 SOC: 0.5970 Cumulative_SOC_deviation: 6.9234 Fuel Consumption: 107.7031
#
# maximum steps, simulation is done ...
# elapsed_time: 61.179
# Episode: 147 Exploration P: 0.0293 Total reward: -155.32144103040602 SOC: 0.5920 Cumulative_SOC_deviation: 8.5262 Fuel Consumption: 106.8651
#
# maximum steps, simulation is done ...
# elapsed_time: 60.828
# Episode: 148 Exploration P: 0.0288 Total reward: -161.84754473281558 SOC: 0.5907 Cumulative_SOC_deviation: 9.6101 Fuel Consumption: 107.2314
#
# maximum steps, simulation is done ...
# elapsed_time: 60.973
# Episode: 149 Exploration P: 0.0283 Total reward: -161.1258438098434 SOC: 0.5928 Cumulative_SOC_deviation: 9.4371 Fuel Consumption: 107.4930
#
# maximum steps, simulation is done ...
# elapsed_time: 60.932
# Episode: 150 Exploration P: 0.0278 Total reward: -191.0989636555674 SOC: 0.5896 Cumulative_SOC_deviation: 14.7301 Fuel Consumption: 107.3848
#
# maximum steps, simulation is done ...
# elapsed_time: 60.925
# Episode: 151 Exploration P: 0.0273 Total reward: -163.19344263126987 SOC: 0.5918 Cumulative_SOC_deviation: 9.7266 Fuel Consumption: 107.9152
#
# maximum steps, simulation is done ...
# elapsed_time: 60.993
# Episode: 152 Exploration P: 0.0268 Total reward: -164.08760205511484 SOC: 0.5910 Cumulative_SOC_deviation: 9.9470 Fuel Consumption: 107.5565
#
# maximum steps, simulation is done ...
# elapsed_time: 60.681
# Episode: 153 Exploration P: 0.0264 Total reward: -162.09075263439877 SOC: 0.5920 Cumulative_SOC_deviation: 9.6610 Fuel Consumption: 107.1851
#
# maximum steps, simulation is done ...
# elapsed_time: 61.095
# Episode: 154 Exploration P: 0.0259 Total reward: -184.38058304252812 SOC: 0.5879 Cumulative_SOC_deviation: 13.5932 Fuel Consumption: 107.1272
#
# maximum steps, simulation is done ...
# elapsed_time: 61.060
# Episode: 155 Exploration P: 0.0255 Total reward: -183.52323844437873 SOC: 0.5884 Cumulative_SOC_deviation: 13.3938 Fuel Consumption: 107.4032
#
# maximum steps, simulation is done ...
# elapsed_time: 61.084
# Episode: 156 Exploration P: 0.0251 Total reward: -188.09452694122623 SOC: 0.5885 Cumulative_SOC_deviation: 14.2030 Fuel Consumption: 107.3757
#
# maximum steps, simulation is done ...
# elapsed_time: 61.306
# Episode: 157 Exploration P: 0.0247 Total reward: -185.67138729569888 SOC: 0.5896 Cumulative_SOC_deviation: 13.8322 Fuel Consumption: 107.0602
#
# maximum steps, simulation is done ...
# elapsed_time: 60.740
# Episode: 158 Exploration P: 0.0243 Total reward: -172.07184784717938 SOC: 0.5899 Cumulative_SOC_deviation: 11.4670 Fuel Consumption: 106.9022
#
# maximum steps, simulation is done ...
# elapsed_time: 61.069
# Episode: 159 Exploration P: 0.0239 Total reward: -191.83041149872764 SOC: 0.5863 Cumulative_SOC_deviation: 14.9752 Fuel Consumption: 106.7231
#
# maximum steps, simulation is done ...
# elapsed_time: 61.071
# Episode: 160 Exploration P: 0.0235 Total reward: -190.20535308142905 SOC: 0.5885 Cumulative_SOC_deviation: 14.6115 Fuel Consumption: 107.1649
#
# maximum steps, simulation is done ...
# elapsed_time: 61.207
# Episode: 161 Exploration P: 0.0232 Total reward: -172.27468662455934 SOC: 0.5891 Cumulative_SOC_deviation: 11.4367 Fuel Consumption: 107.2771
#
# maximum steps, simulation is done ...
# elapsed_time: 61.004
# Episode: 162 Exploration P: 0.0228 Total reward: -182.33629433936673 SOC: 0.5909 Cumulative_SOC_deviation: 13.2522 Fuel Consumption: 107.0210
#
# maximum steps, simulation is done ...
# elapsed_time: 61.217
# Episode: 163 Exploration P: 0.0225 Total reward: -174.20517333112798 SOC: 0.5894 Cumulative_SOC_deviation: 11.8078 Fuel Consumption: 107.0988
# maximum steps, simulation is done ...
# elapsed_time: 61.120
# Episode: 164 Exploration P: 0.0221 Total reward: -169.70544354585482 SOC: 0.5891 Cumulative_SOC_deviation: 11.0365 Fuel Consumption: 106.9825
#
# maximum steps, simulation is done ...
# elapsed_time: 60.764
# Episode: 165 Exploration P: 0.0218 Total reward: -185.74239171446362 SOC: 0.5878 Cumulative_SOC_deviation: 13.8931 Fuel Consumption: 106.7850
#
# maximum steps, simulation is done ...
# elapsed_time: 60.925
# Episode: 166 Exploration P: 0.0215 Total reward: -179.3101733196951 SOC: 0.5874 Cumulative_SOC_deviation: 12.7312 Fuel Consumption: 106.9560
#
# maximum steps, simulation is done ...
# elapsed_time: 60.943
# Episode: 167 Exploration P: 0.0212 Total reward: -180.71676101439573 SOC: 0.5884 Cumulative_SOC_deviation: 12.9454 Fuel Consumption: 107.1452
#
# maximum steps, simulation is done ...
# elapsed_time: 61.010
# Episode: 168 Exploration P: 0.0209 Total reward: -186.42170635985056 SOC: 0.5908 Cumulative_SOC_deviation: 13.9122 Fuel Consumption: 107.3558
#
# maximum steps, simulation is done ...
# elapsed_time: 60.852
# Episode: 169 Exploration P: 0.0206 Total reward: -174.88774131979156 SOC: 0.5891 Cumulative_SOC_deviation: 11.9490 Fuel Consumption: 106.9789
#
# maximum steps, simulation is done ...
# elapsed_time: 61.089
# Episode: 170 Exploration P: 0.0203 Total reward: -198.98121492726992 SOC: 0.5873 Cumulative_SOC_deviation: 16.1254 Fuel Consumption: 107.3368
#
# maximum steps, simulation is done ...
# elapsed_time: 61.210
# Episode: 171 Exploration P: 0.0200 Total reward: -194.50240668201835 SOC: 0.5900 Cumulative_SOC_deviation: 15.3585 Fuel Consumption: 107.2169
#
# maximum steps, simulation is done ...
# elapsed_time: 61.462
# Episode: 172 Exploration P: 0.0197 Total reward: -205.8162745890066 SOC: 0.5910 Cumulative_SOC_deviation: 17.2491 Fuel Consumption: 107.7858
#
# maximum steps, simulation is done ...
# elapsed_time: 61.031
# Episode: 173 Exploration P: 0.0195 Total reward: -171.104740159355 SOC: 0.5953 Cumulative_SOC_deviation: 11.1308 Fuel Consumption: 107.8457
#
# maximum steps, simulation is done ...
# elapsed_time: 62.146
# Episode: 174 Exploration P: 0.0192 Total reward: -180.21426131812055 SOC: 0.5872 Cumulative_SOC_deviation: 12.8830 Fuel Consumption: 106.9976
#
# maximum steps, simulation is done ...
# elapsed_time: 61.698
# Episode: 175 Exploration P: 0.0190 Total reward: -217.0879742645353 SOC: 0.5873 Cumulative_SOC_deviation: 19.3311 Fuel Consumption: 107.2249
#
# maximum steps, simulation is done ...
# elapsed_time: 62.051
# Episode: 176 Exploration P: 0.0187 Total reward: -201.52943474848973 SOC: 0.5875 Cumulative_SOC_deviation: 16.6835 Fuel Consumption: 106.7137
#
# maximum steps, simulation is done ...
# elapsed_time: 61.860
# Episode: 177 Exploration P: 0.0185 Total reward: -194.11750325154847 SOC: 0.5894 Cumulative_SOC_deviation: 15.3312 Fuel Consumption: 106.9869
#
# maximum steps, simulation is done ...
# elapsed_time: 61.887
# Episode: 178 Exploration P: 0.0182 Total reward: -181.32452155885952 SOC: 0.5919 Cumulative_SOC_deviation: 12.9873 Fuel Consumption: 107.5149
#
# maximum steps, simulation is done ...
# elapsed_time: 61.690
# Episode: 179 Exploration P: 0.0180 Total reward: -181.92503531656445 SOC: 0.5934 Cumulative_SOC_deviation: 13.0874 Fuel Consumption: 107.5466
#
# maximum steps, simulation is done ...
# elapsed_time: 61.590
# Episode: 180 Exploration P: 0.0178 Total reward: -184.85197798137617 SOC: 0.5921 Cumulative_SOC_deviation: 13.7044 Fuel Consumption: 106.9669
#
# maximum steps, simulation is done ...
# elapsed_time: 61.538
# Episode: 181 Exploration P: 0.0176 Total reward: -199.50363088798517 SOC: 0.5945 Cumulative_SOC_deviation: 16.1500 Fuel Consumption: 107.7197
#
# maximum steps, simulation is done ...
# elapsed_time: 61.609
# Episode: 182 Exploration P: 0.0174 Total reward: -201.2658627347107 SOC: 0.5840 Cumulative_SOC_deviation: 16.7157 Fuel Consumption: 106.2667
#
# maximum steps, simulation is done ...
# elapsed_time: 61.768
# Episode: 183 Exploration P: 0.0172 Total reward: -199.75314821288904 SOC: 0.5945 Cumulative_SOC_deviation: 16.0972 Fuel Consumption: 108.2694
#
# maximum steps, simulation is done ...
# elapsed_time: 61.543
# Episode: 184 Exploration P: 0.0170 Total reward: -181.34246125624423 SOC: 0.5894 Cumulative_SOC_deviation: 13.1130 Fuel Consumption: 106.8182
#
# maximum steps, simulation is done ...
# elapsed_time: 61.278
# Episode: 185 Exploration P: 0.0168 Total reward: -190.60260828492463 SOC: 0.5919 Cumulative_SOC_deviation: 14.7580 Fuel Consumption: 106.7296
#
# maximum steps, simulation is done ...
# elapsed_time: 61.191
# Episode: 186 Exploration P: 0.0166 Total reward: -189.63542029214204 SOC: 0.5919 Cumulative_SOC_deviation: 14.5265 Fuel Consumption: 107.0782
#
# maximum steps, simulation is done ...
# elapsed_time: 61.018
# Episode: 187 Exploration P: 0.0164 Total reward: -182.15592467763926 SOC: 0.5904 Cumulative_SOC_deviation: 13.2011 Fuel Consumption: 107.1311
#
# maximum steps, simulation is done ...
# elapsed_time: 61.048
# Episode: 188 Exploration P: 0.0163 Total reward: -198.6356168719332 SOC: 0.5858 Cumulative_SOC_deviation: 16.1248 Fuel Consumption: 106.9949
#
# maximum steps, simulation is done ...
# elapsed_time: 61.025
# Episode: 189 Exploration P: 0.0161 Total reward: -208.03309639241078 SOC: 0.5855 Cumulative_SOC_deviation: 17.7989 Fuel Consumption: 106.8781
#
# maximum steps, simulation is done ...
# elapsed_time: 61.215
# Episode: 190 Exploration P: 0.0159 Total reward: -198.72154697712716 SOC: 0.5893 Cumulative_SOC_deviation: 16.1109 Fuel Consumption: 107.1600
#
# maximum steps, simulation is done ...
# elapsed_time: 60.887
# Episode: 191 Exploration P: 0.0158 Total reward: -198.64093076951727 SOC: 0.5896 Cumulative_SOC_deviation: 16.1104 Fuel Consumption: 107.0820
#
# maximum steps, simulation is done ...
# elapsed_time: 60.964
# Episode: 192 Exploration P: 0.0156 Total reward: -205.58173484014227 SOC: 0.5852 Cumulative_SOC_deviation: 17.3733 Fuel Consumption: 106.8454
#
# maximum steps, simulation is done ...
# elapsed_time: 61.018
# Episode: 193 Exploration P: 0.0155 Total reward: -204.5257656357068 SOC: 0.5892 Cumulative_SOC_deviation: 17.1710 Fuel Consumption: 106.9390
#
# maximum steps, simulation is done ...
# elapsed_time: 61.588
# Episode: 194 Exploration P: 0.0153 Total reward: -182.01646940897518 SOC: 0.5888 Cumulative_SOC_deviation: 13.2476 Fuel Consumption: 106.7272
#
# maximum steps, simulation is done ...
# elapsed_time: 61.999
# Episode: 195 Exploration P: 0.0152 Total reward: -190.57397334341428 SOC: 0.5862 Cumulative_SOC_deviation: 14.7536 Fuel Consumption: 106.7261
#
# maximum steps, simulation is done ...
# elapsed_time: 61.804
# Episode: 196 Exploration P: 0.0150 Total reward: -212.4629841414514 SOC: 0.5848 Cumulative_SOC_deviation: 18.5927 Fuel Consumption: 106.7967
#
# maximum steps, simulation is done ...
# elapsed_time: 61.137
# Episode: 197 Exploration P: 0.0149 Total reward: -217.86258823381257 SOC: 0.5834 Cumulative_SOC_deviation: 19.6502 Fuel Consumption: 106.1859
#
# maximum steps, simulation is done ...
# elapsed_time: 61.201
# Episode: 198 Exploration P: 0.0148 Total reward: -199.2186968886831 SOC: 0.5869 Cumulative_SOC_deviation: 16.3303 Fuel Consumption: 106.4098
#
# maximum steps, simulation is done ...
# elapsed_time: 60.782
# Episode: 199 Exploration P: 0.0146 Total reward: -184.82174836818558 SOC: 0.5875 Cumulative_SOC_deviation: 13.7951 Fuel Consumption: 106.4214
#
# maximum steps, simulation is done ...
# elapsed_time: 60.891
# Episode: 200 Exploration P: 0.0145 Total reward: -184.32154680683752 SOC: 0.5889 Cumulative_SOC_deviation: 13.6795 Fuel Consumption: 106.5779
#
# model is saved..

# %%
with open("DDPG_adaptive_reward_factor.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)

# %%
# results_dict
