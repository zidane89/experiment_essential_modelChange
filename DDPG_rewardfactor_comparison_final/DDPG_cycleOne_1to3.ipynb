# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras 
import os 
import math 
import random 
import pickle 
import glob
import matplotlib.pyplot as plt 
from collections import deque 
from tensorflow.keras import layers
import time 
import scipy.io as sio

from vehicle_model_variant import Environment 
from cell_model import CellModel 
from driver_MDP import Driver_MDP 

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
drving_cycle = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
battery_path = "../../OC_SIM_DB/OC_SIM_DB_Bat/OC_SIM_DB_Bat_nimh_6_240_panasonic_MY01_Prius.mat"
motor_path = "../../OC_SIM_DB/OC_SIM_DB_Mot/OC_SIM_DB_Mot_pm_95_145_X2.mat"
cell_model = CellModel()
# env = Environment(cell_model, drving_cycle, battery_path, motor_path, 10)
driver = Driver_MDP(0.02)

num_states = 4

# %%
class OUActionNoise: 
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None): 
        self.theta = theta 
        self.mean = mean 
        self.std_dev = std_deviation 
        self.dt = dt 
        self.x_initial = x_initial 
        self.reset() 
        
    def reset(self): 
        if self.x_initial is not None: 
            self.x_prev = self.x_initial 
        else: 
            self.x_prev = 0 
            
    def __call__(self): 
        x = (
             self.x_prev + self.theta * (self.mean - self.x_prev) * self.dt 
            + self.std_dev * np.sqrt(self.dt) * np.random.normal() 
        )
        self.x_prev = x 
        return x

# %%
class Buffer: 
    def __init__(self, buffer_capacity=100000, batch_size=64):      
        self.buffer_capacity = buffer_capacity 
        self.batch_size = batch_size 
        self.buffer_counter = 0 
        
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, 1))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))
        
    def record(self, obs_tuple):
        index = self.buffer_counter % self.buffer_capacity 

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]
        
        self.buffer_counter += 1 
        
    def learn(self): 
        record_range = min(self.buffer_counter, self.buffer_capacity)
        batch_indices = np.random.choice(record_range, self.batch_size)

        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])
        
        with tf.GradientTape() as tape: 
            target_actions = target_actor(next_state_batch)
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions])
            critic_value = critic_model([state_batch, action_batch])
            critic_loss = tf.math.reduce_mean(tf.square(y - critic_value)) 
        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables) 
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )
        
        with tf.GradientTape() as tape: 
            actions = actor_model(state_batch)
            critic_value = critic_model([state_batch, actions])
            actor_loss = - tf.math.reduce_mean(critic_value)
        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables) 
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

# %%
def update_target(tau): 
    new_weights = [] 
    target_variables = target_critic.weights
    for i, variable in enumerate(critic_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_critic.set_weights(new_weights)
    
    new_weights = [] 
    target_variables = target_actor.weights
    for i, variable in enumerate(actor_model.weights): 
        new_weights.append(target_variables[i] * (1 - tau) + tau * variable)
    target_actor.set_weights(new_weights)

# %%
def get_actor(): 
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)
    
    inputs = layers.Input(shape=(num_states))
    inputs_batchnorm = layers.BatchNormalization()(inputs)
    
    out = layers.Dense(512, activation="relu")(inputs_batchnorm)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1, activation="sigmoid", 
                          kernel_initializer=last_init)(out)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
def get_critic(): 
    state_input = layers.Input(shape=(num_states))
    state_input_batchnorm = layers.BatchNormalization()(state_input)
    
    state_out = layers.Dense(16, activation="relu")(state_input_batchnorm)
#     state_out = layers.BatchNormalization()(state_out)
    state_out = layers.Dense(32, activation="relu")(state_out)
#     state_out = layers.BatchNormalization()(state_out)
    
    action_input = layers.Input(shape=(1))
    action_out = layers.Dense(32, activation="relu")(action_input)
#     action_out = layers.BatchNormalization()(action_out)
    
    concat = layers.Concatenate()([state_out, action_out]) 
    
    out = layers.Dense(512, activation="relu")(concat)
#     out = layers.BatchNormalization()(out)
    out = layers.Dense(512, activation="relu")(out)
#     out = layers.BatchNormalization()(out)
    outputs = layers.Dense(1)(out)
    
    model = tf.keras.Model([state_input, action_input], outputs)
    return model

# %%
def policy(state, noise_object): 
    j_min = state[0][2].numpy()
    j_max = state[0][3].numpy()
    sampled_action = tf.squeeze(actor_model(state)) 
    noise = noise_object()
    sampled_action = sampled_action.numpy() + noise 
    legal_action = sampled_action * j_max 
    legal_action = np.clip(legal_action, j_min, j_max)
#     print(j_min, j_max, legal_action, noise)
    return legal_action

# %%
def policy_epsilon_greedy(state, eps): 
    j_min = state[0][-2].numpy()
    j_max = state[0][-1].numpy()

    if random.random() < eps: 
        a = random.randint(0, 9)
        return np.linspace(j_min, j_max, 10)[a]
    else: 
        sampled_action = tf.squeeze(actor_model(state)).numpy()  
        legal_action = sampled_action * j_max 
        legal_action = np.clip(legal_action, j_min, j_max)
        return legal_action

# %%
std_dev = 0.2 
ou_noise = OUActionNoise(mean=0, std_deviation=0.2)

critic_lr = 0.0005 
actor_lr = 0.00025 
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 200 
gamma = 0.95 
tau = 0.001 

MAX_EPSILON = 1.0 
MIN_EPSILON = 0.01 
DECAY_RATE = 0.00002
BATCH_SIZE = 32 
DELAY_TRAINING = 5000

# %%
def initialization(): 
    actor_model = get_actor() 
    critic_model = get_critic() 
    target_actor = get_actor() 
    target_critic = get_critic() 
    target_actor.set_weights(actor_model.get_weights())
    target_critic.set_weights(critic_model.get_weights())
#     actor_model.load_weights("./DDPG1_trial1/actor_model_checkpoint")
#     critic_model.load_weights("./DDPG1_trial1/critic_model_checkpoint")
#     target_actor.load_weights("./DDPG1_trial1/target_actor_checkpoint")
#     target_critic.load_weights("./DDPG1_trial1/target_critic_checkpoint")
    
    buffer = Buffer(500000, BATCH_SIZE)
    return actor_model, critic_model, target_actor, target_critic, buffer

# %%
def save_weights(actor_model, critic_model, target_actor, target_critic, root): 
    if not os.path.exists(root): 
        os.makedirs(root)
        
    actor_model.save_weights("./{}/actor_model.h5".format(root))
    critic_model.save_weights("./{}/critic_model.h5".format(root))
    target_actor.save_weights("./{}/target_actor.h5".format(root))
    target_critic.save_weights("./{}/target_critic.h5".format(root))
    print("model is saved..")

# %%
def initialization_env(driving_path, reward_factor):
    env = Environment(cell_model, driving_path, battery_path, motor_path, reward_factor)
    return env

# %%
def test_agent(actor_model, reward_factor):
#     test_cycle = driver.get_cycle() 
    test_cycle_path = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
    test_cycle = sio.loadmat(test_cycle_path)
    test_cycle = test_cycle["sch_cycle"][:, 1]
    env = initialization_env(test_cycle, reward_factor)
    
    total_reward = 0
    state = env.reset() 
    while True: 
        tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
        action = policy_epsilon_greedy(tf_state, -1)
        next_state, reward, done = env.step(action)
        
        state = next_state 
        total_reward += reward 
        
        if done: 
            break 
        
    SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
    
    print("******************* Test is start *****************")
#     print(test_cycle)
    print('Total reward: {}'.format(total_reward), 
          "SOC: {:.4f}".format(env.SOC), 
          "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
          "Fuel Consumption: {:.4f}".format(env.fuel_consumption))
    print("******************* Test is done *****************")
    print("")
    plt.subplot(1, 2, 1)
    plt.plot(test_cycle)
    plt.subplot(1, 2, 2)
    plt.plot(env.history["Action"])
    plt.show() 
    return env.history

# %%
# print(env.version)

# num_trials = 1
reward_factors = [1, 2, 3]
results_dict = {} 
driving_cycle_path = '../../OC_SIM_DB/OC_SIM_DB_Cycles/Highway/01_FTP72_fuds.mat'
driving_cycle = sio.loadmat(driving_cycle_path)
driving_cycle = driving_cycle["sch_cycle"][:, 1]

for reward_factor in reward_factors: 
    print("")
    print("Trial {}".format(reward_factor))
    print("")
    
    actor_model, critic_model, target_actor, target_critic, buffer = initialization()
    
    eps = MAX_EPSILON 
    steps = 0
    
    episode_rewards = [] 
    episode_SOCs = [] 
    episode_FCs = [] 
    episode_test_history = [] 
    episode_num_test = [] 
    for ep in range(total_episodes): 
#         driving_cycle = driver.get_cycle() 
        env = initialization_env(driving_cycle, reward_factor)
        
        start = time.time() 
        state = env.reset() 
        episodic_reward = 0 

        while True: 
            tf_state = tf.expand_dims(tf.convert_to_tensor(state), 0)
            action = policy_epsilon_greedy(tf_state, eps)
    #         print(action)
            next_state, reward, done = env.step(action)
            if done: 
                next_state = [0] * num_states 

            buffer.record((state, action, reward, next_state))
            episodic_reward += reward 

            if steps > DELAY_TRAINING: 
                buffer.learn() 
                update_target(tau)
                eps = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * np.exp(-DECAY_RATE * (steps
                                                                        -DELAY_TRAINING))

            steps += 1

            if done: 
                break 

            state = next_state 

        elapsed_time = time.time() - start 
        print("elapsed_time: {:.3f}".format(elapsed_time))
        episode_rewards.append(episodic_reward) 
        episode_SOCs.append(env.SOC)
        episode_FCs.append(env.fuel_consumption) 

    #     print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
        SOC_deviation_history = np.sum(np.abs(np.array(env.history["SOC"]) - 0.6)) 
        print(
              'Episode: {}'.format(ep + 1),
              "Exploration P: {:.4f}".format(eps),
              'Total reward: {}'.format(episodic_reward), 
              "SOC: {:.4f}".format(env.SOC), 
              "Cumulative_SOC_deviation: {:.4f}".format(SOC_deviation_history), 
              "Fuel Consumption: {:.4f}".format(env.fuel_consumption), 
        )
        print("")
        
        if (ep + 1) % 10 == 0: 
#             history = test_agent(actor_model, reward_factor)
            history = env.history 
            episode_test_history.append(history) 
            episode_num_test.append(ep + 1)
            
#         if (ep + 1) % 200 == 0:             
    root = "DDPG_cycleOne_reward_factor{}".format(reward_factor)
    save_weights(actor_model, critic_model, target_actor, target_critic, root)
            
    
    results_dict[reward_factor] = {
        "rewards": episode_rewards, 
        "SOCs": episode_SOCs, 
        "FCs": episode_FCs, 
        "test_history": episode_test_history, 
        "test_episode_num": episode_num_test, 
    }
# Out:
# Trial 1
#
# maximum steps, simulation is done ...
# elapsed_time: 9.183
# Episode: 1 Exploration P: 1.0000 Total reward: -669.6301542086956 SOC: 1.0000 Cumulative_SOC_deviation: 481.0124 Fuel Consumption: 188.6177
#
# maximum steps, simulation is done ...
# elapsed_time: 9.215
# Episode: 2 Exploration P: 1.0000 Total reward: -676.4870294699607 SOC: 1.0000 Cumulative_SOC_deviation: 485.6016 Fuel Consumption: 190.8855
#
# maximum steps, simulation is done ...
# elapsed_time: 9.735
# Episode: 3 Exploration P: 1.0000 Total reward: -679.2840680106785 SOC: 1.0000 Cumulative_SOC_deviation: 486.4813 Fuel Consumption: 192.8027
#
# WARNING:tensorflow:Layer batch_normalization_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# maximum steps, simulation is done ...
# elapsed_time: 31.474
# Episode: 4 Exploration P: 0.9903 Total reward: -687.4333339647756 SOC: 1.0000 Cumulative_SOC_deviation: 490.2600 Fuel Consumption: 197.1733
#
# maximum steps, simulation is done ...
# elapsed_time: 91.758
# Episode: 5 Exploration P: 0.9638 Total reward: -671.3495485428142 SOC: 1.0000 Cumulative_SOC_deviation: 482.4535 Fuel Consumption: 188.8960
#
# maximum steps, simulation is done ...
# elapsed_time: 85.121
# Episode: 6 Exploration P: 0.9379 Total reward: -647.8525128376053 SOC: 0.9994 Cumulative_SOC_deviation: 465.9556 Fuel Consumption: 181.8970
#
# maximum steps, simulation is done ...
# elapsed_time: 85.357
# Episode: 7 Exploration P: 0.9128 Total reward: -664.6243015537228 SOC: 1.0000 Cumulative_SOC_deviation: 479.3463 Fuel Consumption: 185.2780
#
# maximum steps, simulation is done ...
# elapsed_time: 84.301
# Episode: 8 Exploration P: 0.8883 Total reward: -643.1564004713456 SOC: 0.9993 Cumulative_SOC_deviation: 462.4036 Fuel Consumption: 180.7528
#
# maximum steps, simulation is done ...
# elapsed_time: 108.429
# Episode: 9 Exploration P: 0.8646 Total reward: -638.6429244644926 SOC: 0.9984 Cumulative_SOC_deviation: 465.5799 Fuel Consumption: 173.0631
#
# maximum steps, simulation is done ...
# elapsed_time: 113.651
# Episode: 10 Exploration P: 0.8414 Total reward: -617.1834003571267 SOC: 0.9999 Cumulative_SOC_deviation: 446.8829 Fuel Consumption: 170.3005
#
# maximum steps, simulation is done ...
# elapsed_time: 105.205
# Episode: 11 Exploration P: 0.8189 Total reward: -629.9138156838732 SOC: 0.9994 Cumulative_SOC_deviation: 459.1288 Fuel Consumption: 170.7850
#
# maximum steps, simulation is done ...
# elapsed_time: 104.752
# Episode: 12 Exploration P: 0.7970 Total reward: -618.1738887450595 SOC: 0.9987 Cumulative_SOC_deviation: 451.6460 Fuel Consumption: 166.5278
#
# maximum steps, simulation is done ...
# elapsed_time: 105.482
# Episode: 13 Exploration P: 0.7757 Total reward: -606.2621110264214 SOC: 0.9990 Cumulative_SOC_deviation: 440.8166 Fuel Consumption: 165.4455
#
# maximum steps, simulation is done ...
# elapsed_time: 101.005
# Episode: 14 Exploration P: 0.7549 Total reward: -575.1530380409928 SOC: 0.9977 Cumulative_SOC_deviation: 415.0367 Fuel Consumption: 160.1163
#
# maximum steps, simulation is done ...
# elapsed_time: 101.708
# Episode: 15 Exploration P: 0.7347 Total reward: -577.4496602597984 SOC: 1.0000 Cumulative_SOC_deviation: 416.3541 Fuel Consumption: 161.0956
#
# maximum steps, simulation is done ...
# elapsed_time: 103.554
# Episode: 16 Exploration P: 0.7151 Total reward: -560.4027240415973 SOC: 0.9891 Cumulative_SOC_deviation: 405.0693 Fuel Consumption: 155.3334
#
# maximum steps, simulation is done ...
# elapsed_time: 103.000
# Episode: 17 Exploration P: 0.6960 Total reward: -542.4449119978763 SOC: 0.9967 Cumulative_SOC_deviation: 388.2144 Fuel Consumption: 154.2305
#
# maximum steps, simulation is done ...
# elapsed_time: 101.745
# Episode: 18 Exploration P: 0.6774 Total reward: -530.5591631435874 SOC: 0.9948 Cumulative_SOC_deviation: 374.0712 Fuel Consumption: 156.4879
#
# maximum steps, simulation is done ...
# elapsed_time: 101.922
# Episode: 19 Exploration P: 0.6594 Total reward: -540.6086464023058 SOC: 0.9954 Cumulative_SOC_deviation: 384.8217 Fuel Consumption: 155.7870
#
# maximum steps, simulation is done ...
# elapsed_time: 97.173
# Episode: 20 Exploration P: 0.6418 Total reward: -483.63150123123864 SOC: 0.9854 Cumulative_SOC_deviation: 331.9677 Fuel Consumption: 151.6638
#
# maximum steps, simulation is done ...
# elapsed_time: 81.005
# Episode: 21 Exploration P: 0.6247 Total reward: -461.2654950164435 SOC: 0.9968 Cumulative_SOC_deviation: 307.8287 Fuel Consumption: 153.4368
#
# maximum steps, simulation is done ...
# elapsed_time: 81.005
# Episode: 22 Exploration P: 0.6080 Total reward: -371.44873538098335 SOC: 0.9885 Cumulative_SOC_deviation: 217.7749 Fuel Consumption: 153.6739
#
# maximum steps, simulation is done ...
# elapsed_time: 80.998
# Episode: 23 Exploration P: 0.5918 Total reward: -326.26279022380635 SOC: 0.9351 Cumulative_SOC_deviation: 175.6607 Fuel Consumption: 150.6021
#
# maximum steps, simulation is done ...
# elapsed_time: 80.953
# Episode: 24 Exploration P: 0.5761 Total reward: -359.6950536225253 SOC: 0.9448 Cumulative_SOC_deviation: 208.4126 Fuel Consumption: 151.2824
#
# maximum steps, simulation is done ...
# elapsed_time: 88.565
# Episode: 25 Exploration P: 0.5607 Total reward: -239.43925209613764 SOC: 0.7933 Cumulative_SOC_deviation: 98.9492 Fuel Consumption: 140.4900
#
# maximum steps, simulation is done ...
# elapsed_time: 82.780
# Episode: 26 Exploration P: 0.5458 Total reward: -354.1394434306223 SOC: 0.9536 Cumulative_SOC_deviation: 202.8158 Fuel Consumption: 151.3237
#
# maximum steps, simulation is done ...
# elapsed_time: 86.412
# Episode: 27 Exploration P: 0.5313 Total reward: -222.69320046468937 SOC: 0.8245 Cumulative_SOC_deviation: 79.8220 Fuel Consumption: 142.8712
# maximum steps, simulation is done ...
# elapsed_time: 85.941
# Episode: 28 Exploration P: 0.5172 Total reward: -252.02888495345096 SOC: 0.7988 Cumulative_SOC_deviation: 110.7555 Fuel Consumption: 141.2734
#
# maximum steps, simulation is done ...
# elapsed_time: 88.245
# Episode: 29 Exploration P: 0.5034 Total reward: -228.27196514526017 SOC: 0.8119 Cumulative_SOC_deviation: 85.7822 Fuel Consumption: 142.4898
#
# maximum steps, simulation is done ...
# elapsed_time: 86.816
# Episode: 30 Exploration P: 0.4901 Total reward: -207.32358707736768 SOC: 0.7098 Cumulative_SOC_deviation: 72.5441 Fuel Consumption: 134.7794
#
# maximum steps, simulation is done ...
# elapsed_time: 88.213
# Episode: 31 Exploration P: 0.4771 Total reward: -208.99212990416424 SOC: 0.7334 Cumulative_SOC_deviation: 72.1923 Fuel Consumption: 136.7998
#
# maximum steps, simulation is done ...
# elapsed_time: 86.177
# Episode: 32 Exploration P: 0.4644 Total reward: -197.18436552198955 SOC: 0.5708 Cumulative_SOC_deviation: 72.9912 Fuel Consumption: 124.1932
#
# maximum steps, simulation is done ...
# elapsed_time: 83.845
# Episode: 33 Exploration P: 0.4521 Total reward: -227.15260214548812 SOC: 0.5262 Cumulative_SOC_deviation: 106.8352 Fuel Consumption: 120.3174
#
# maximum steps, simulation is done ...
# elapsed_time: 86.220
# Episode: 34 Exploration P: 0.4401 Total reward: -234.0012494455625 SOC: 0.5910 Cumulative_SOC_deviation: 108.1072 Fuel Consumption: 125.8940
#
# maximum steps, simulation is done ...
# elapsed_time: 86.777
# Episode: 35 Exploration P: 0.4285 Total reward: -286.41567483192284 SOC: 0.5281 Cumulative_SOC_deviation: 164.6551 Fuel Consumption: 121.7605
#
# maximum steps, simulation is done ...
# elapsed_time: 97.556
# Episode: 36 Exploration P: 0.4171 Total reward: -269.42245403041915 SOC: 0.4790 Cumulative_SOC_deviation: 152.3211 Fuel Consumption: 117.1014
#
# maximum steps, simulation is done ...
# elapsed_time: 88.215
# Episode: 37 Exploration P: 0.4061 Total reward: -353.9339722061019 SOC: 0.3962 Cumulative_SOC_deviation: 242.2134 Fuel Consumption: 111.7206
#
# maximum steps, simulation is done ...
# elapsed_time: 88.007
# Episode: 38 Exploration P: 0.3954 Total reward: -461.30122159995364 SOC: 0.2582 Cumulative_SOC_deviation: 359.3628 Fuel Consumption: 101.9384
#
# maximum steps, simulation is done ...
# elapsed_time: 88.595
# Episode: 39 Exploration P: 0.3849 Total reward: -320.34135617387017 SOC: 0.3722 Cumulative_SOC_deviation: 211.3111 Fuel Consumption: 109.0303
#
# maximum steps, simulation is done ...
# elapsed_time: 96.534
# Episode: 40 Exploration P: 0.3748 Total reward: -449.3661225678399 SOC: 0.2526 Cumulative_SOC_deviation: 348.0771 Fuel Consumption: 101.2890
#
# maximum steps, simulation is done ...
# elapsed_time: 87.466
# Episode: 41 Exploration P: 0.3649 Total reward: -396.8779282477504 SOC: 0.2706 Cumulative_SOC_deviation: 294.4757 Fuel Consumption: 102.4023
#
# maximum steps, simulation is done ...
# elapsed_time: 80.260
# Episode: 42 Exploration P: 0.3553 Total reward: -501.5017867416864 SOC: 0.1454 Cumulative_SOC_deviation: 406.6243 Fuel Consumption: 94.8775
#
# maximum steps, simulation is done ...
# elapsed_time: 79.621
# Episode: 43 Exploration P: 0.3459 Total reward: -408.7904113790254 SOC: 0.2334 Cumulative_SOC_deviation: 308.6044 Fuel Consumption: 100.1861
# C:\Users\ValueCreatorSong\Desktop\Academic\graduate_paper\degradation_model\experiment_essential_modelChange\DDPG_rewardfactor_comparison_final\vehicle_model_variant.py:251: RuntimeWarning: invalid value encountered in double_scalars
#   del_i = (1 / (2 * r_cha)) * (v_cha - (v_cha ** 2 - 4 * r_cha * p_bat) ** (0.5)) * (p_bat < 0) + (1 / (
# maximum steps, simulation is done ...
# elapsed_time: 79.754
# Episode: 44 Exploration P: 0.3368 Total reward: -593.2858489213535 SOC: 0.0289 Cumulative_SOC_deviation: 505.9538 Fuel Consumption: 87.3321
#
# maximum steps, simulation is done ...
# elapsed_time: 80.379
# Episode: 45 Exploration P: 0.3280 Total reward: -447.37486371392083 SOC: 0.1661 Cumulative_SOC_deviation: 352.2500 Fuel Consumption: 95.1249
#
# maximum steps, simulation is done ...
# elapsed_time: 79.680
# Episode: 46 Exploration P: 0.3194 Total reward: -560.9083022402615 SOC: 0.0608 Cumulative_SOC_deviation: 472.0404 Fuel Consumption: 88.8680
#
# maximum steps, simulation is done ...
# elapsed_time: 79.935
# Episode: 47 Exploration P: 0.3110 Total reward: -559.2155137571144 SOC: 0.0409 Cumulative_SOC_deviation: 471.7597 Fuel Consumption: 87.4558
#
# battery power is 7946.590307366354(+) but condition is not avail
# elapsed_time: 65.825
# Episode: 48 Exploration P: 0.3043 Total reward: -1466.5895096886507 SOC: -0.0014 Cumulative_SOC_deviation: 399.1196 Fuel Consumption: 68.0721
#
# battery power is 8510.67186926024(+) but condition is not avail
# elapsed_time: 75.697
# Episode: 49 Exploration P: 0.2967 Total reward: -1571.0561419169148 SOC: -0.0004 Cumulative_SOC_deviation: 489.7250 Fuel Consumption: 81.9324
#
# battery power is 17424.903515111262(+) but condition is not avail
# elapsed_time: 75.388
# Episode: 50 Exploration P: 0.2893 Total reward: -1542.187984227823 SOC: -0.0014 Cumulative_SOC_deviation: 461.4161 Fuel Consumption: 81.3741
#
# battery power is 4062.559117293534(+) but condition is not avail
# elapsed_time: 71.304
# Episode: 51 Exploration P: 0.2826 Total reward: -1543.3315718286158 SOC: -0.0004 Cumulative_SOC_deviation: 468.1414 Fuel Consumption: 75.7914
#
# battery power is 9390.89364241311(+) but condition is not avail
# elapsed_time: 65.409
# Episode: 52 Exploration P: 0.2765 Total reward: -1462.6589618154828 SOC: -0.0010 Cumulative_SOC_deviation: 395.9986 Fuel Consumption: 67.2623
#
# battery power is 10047.65538460892(+) but condition is not avail
# elapsed_time: 74.156
# Episode: 53 Exploration P: 0.2698 Total reward: -1533.40801048481 SOC: -0.0012 Cumulative_SOC_deviation: 455.5802 Fuel Consumption: 78.4299
#
# maximum steps, simulation is done ...
# elapsed_time: 79.612
# Episode: 54 Exploration P: 0.2627 Total reward: -528.6945058533738 SOC: 0.0435 Cumulative_SOC_deviation: 441.1975 Fuel Consumption: 87.4970
#
# battery power is 7274.122387822343(+) but condition is not avail
# elapsed_time: 54.902
# Episode: 55 Exploration P: 0.2580 Total reward: -1364.2251879179532 SOC: -0.0000 Cumulative_SOC_deviation: 312.2372 Fuel Consumption: 52.5888
#
# battery power is 5868.2091315251355(+) but condition is not avail
# elapsed_time: 51.323
# Episode: 56 Exploration P: 0.2536 Total reward: -1325.880368771589 SOC: -0.0005 Cumulative_SOC_deviation: 279.8632 Fuel Consumption: 46.6186
#
# battery power is 8370.966351628711(+) but condition is not avail
# elapsed_time: 52.846
# Episode: 57 Exploration P: 0.2492 Total reward: -1350.8641698370452 SOC: -0.0000 Cumulative_SOC_deviation: 301.0813 Fuel Consumption: 50.3837
# C:\Users\ValueCreatorSong\Desktop\Academic\graduate_paper\degradation_model\experiment_essential_modelChange\DDPG_rewardfactor_comparison_final\vehicle_model_variant.py:252: RuntimeWarning: invalid value encountered in double_scalars
#   2 * r_dis)) * (v_dis - (v_dis ** 2 - 4 * r_dis * p_bat) ** (0.5)) * (p_bat >= 0)
# battery power is 6435.155063651266(+) but condition is not avail
# elapsed_time: 45.941
# Episode: 58 Exploration P: 0.2455 Total reward: -1302.9170900773852 SOC: -0.0004 Cumulative_SOC_deviation: 265.4635 Fuel Consumption: 38.0549
#
# maximum steps, simulation is done ...
# elapsed_time: 79.803
# Episode: 59 Exploration P: 0.2391 Total reward: -422.8540661967853 SOC: 0.4991 Cumulative_SOC_deviation: 301.9368 Fuel Consumption: 120.9173
#
# maximum steps, simulation is done ...
# elapsed_time: 80.610
# Episode: 60 Exploration P: 0.2329 Total reward: -202.46087921589722 SOC: 0.5036 Cumulative_SOC_deviation: 87.3758 Fuel Consumption: 115.0851
#
# maximum steps, simulation is done ...
# elapsed_time: 79.985
# Episode: 61 Exploration P: 0.2269 Total reward: -333.87300838985215 SOC: 0.4933 Cumulative_SOC_deviation: 217.5524 Fuel Consumption: 116.3206
#
# maximum steps, simulation is done ...
# elapsed_time: 80.022
# Episode: 62 Exploration P: 0.2210 Total reward: -399.2780202631183 SOC: 0.5090 Cumulative_SOC_deviation: 279.6059 Fuel Consumption: 119.6721
#
# maximum steps, simulation is done ...
# elapsed_time: 79.880
# Episode: 63 Exploration P: 0.2153 Total reward: -302.83557282412175 SOC: 0.4764 Cumulative_SOC_deviation: 186.6811 Fuel Consumption: 116.1545
#
# maximum steps, simulation is done ...
# elapsed_time: 79.782
# Episode: 64 Exploration P: 0.2097 Total reward: -384.0847662783435 SOC: 0.3104 Cumulative_SOC_deviation: 279.1337 Fuel Consumption: 104.9510
#
# maximum steps, simulation is done ...
# elapsed_time: 90.041
# Episode: 65 Exploration P: 0.2043 Total reward: -587.8809497884334 SOC: 0.2145 Cumulative_SOC_deviation: 488.1400 Fuel Consumption: 99.7409
#
# maximum steps, simulation is done ...
# elapsed_time: 105.707
# Episode: 66 Exploration P: 0.1991 Total reward: -399.74555604503934 SOC: 0.4000 Cumulative_SOC_deviation: 289.0210 Fuel Consumption: 110.7246
#
# maximum steps, simulation is done ...
# elapsed_time: 105.304
# Episode: 67 Exploration P: 0.1939 Total reward: -328.67287306893434 SOC: 0.4847 Cumulative_SOC_deviation: 214.6566 Fuel Consumption: 114.0162
#
# maximum steps, simulation is done ...
# elapsed_time: 106.106
# Episode: 68 Exploration P: 0.1890 Total reward: -309.0343308853968 SOC: 0.4374 Cumulative_SOC_deviation: 195.4713 Fuel Consumption: 113.5630
#
# maximum steps, simulation is done ...
# elapsed_time: 105.007
# Episode: 69 Exploration P: 0.1841 Total reward: -345.1987199153494 SOC: 0.2842 Cumulative_SOC_deviation: 246.3633 Fuel Consumption: 98.8354
#
# maximum steps, simulation is done ...
# elapsed_time: 106.484
# Episode: 70 Exploration P: 0.1794 Total reward: -549.6548389513639 SOC: 0.2186 Cumulative_SOC_deviation: 453.7884 Fuel Consumption: 95.8664
#
# maximum steps, simulation is done ...
# elapsed_time: 101.309
# Episode: 71 Exploration P: 0.1748 Total reward: -446.4343557394033 SOC: 0.3688 Cumulative_SOC_deviation: 339.7429 Fuel Consumption: 106.6914
#
# maximum steps, simulation is done ...
# elapsed_time: 83.240
# Episode: 72 Exploration P: 0.1703 Total reward: -559.1778330946601 SOC: 0.1318 Cumulative_SOC_deviation: 466.7704 Fuel Consumption: 92.4075
#
# maximum steps, simulation is done ...
# elapsed_time: 92.285
# Episode: 73 Exploration P: 0.1660 Total reward: -576.4981074023113 SOC: 0.1421 Cumulative_SOC_deviation: 484.6673 Fuel Consumption: 91.8308
#
# maximum steps, simulation is done ...
# elapsed_time: 120.089
# Episode: 74 Exploration P: 0.1618 Total reward: -456.0707624314556 SOC: 0.3165 Cumulative_SOC_deviation: 356.9407 Fuel Consumption: 99.1300
#
# maximum steps, simulation is done ...
# elapsed_time: 112.984
# Episode: 75 Exploration P: 0.1577 Total reward: -393.2371869614742 SOC: 0.2802 Cumulative_SOC_deviation: 289.4135 Fuel Consumption: 103.8237
#
# maximum steps, simulation is done ...
# elapsed_time: 120.792
# Episode: 76 Exploration P: 0.1537 Total reward: -503.99872533962684 SOC: 0.2476 Cumulative_SOC_deviation: 403.2290 Fuel Consumption: 100.7697
#
# maximum steps, simulation is done ...
# elapsed_time: 112.069
# Episode: 77 Exploration P: 0.1498 Total reward: -469.8887868281713 SOC: 0.3081 Cumulative_SOC_deviation: 365.0646 Fuel Consumption: 104.8242
#
# maximum steps, simulation is done ...
# elapsed_time: 117.860
# Episode: 78 Exploration P: 0.1460 Total reward: -533.511303580707 SOC: 0.2301 Cumulative_SOC_deviation: 436.1550 Fuel Consumption: 97.3563
#
# battery power is 1877.1324522208151(+) but condition is not avail
# elapsed_time: 61.862
# Episode: 79 Exploration P: 0.1440 Total reward: -1276.8445275243052 SOC: -0.0002 Cumulative_SOC_deviation: 247.2628 Fuel Consumption: 30.1828
#
# maximum steps, simulation is done ...
# elapsed_time: 110.367
# Episode: 80 Exploration P: 0.1404 Total reward: -564.0421240922965 SOC: 0.2120 Cumulative_SOC_deviation: 468.5110 Fuel Consumption: 95.5312
#
# battery power is 11575.727303484833(+) but condition is not avail
# elapsed_time: 88.608
# Episode: 81 Exploration P: 0.1376 Total reward: -1516.0480738296449 SOC: -0.0001 Cumulative_SOC_deviation: 454.6652 Fuel Consumption: 62.0034
#
# maximum steps, simulation is done ...
# elapsed_time: 109.588
# Episode: 82 Exploration P: 0.1341 Total reward: -636.5897216887188 SOC: 0.1754 Cumulative_SOC_deviation: 544.4964 Fuel Consumption: 92.0933
#
# maximum steps, simulation is done ...
# elapsed_time: 107.753
# Episode: 83 Exploration P: 0.1307 Total reward: -617.0817840573113 SOC: 0.1314 Cumulative_SOC_deviation: 527.5882 Fuel Consumption: 89.4935
#
# maximum steps, simulation is done ...
# elapsed_time: 109.120
# Episode: 84 Exploration P: 0.1275 Total reward: -572.8151786693824 SOC: 0.1798 Cumulative_SOC_deviation: 481.5529 Fuel Consumption: 91.2623
#
# maximum steps, simulation is done ...
# elapsed_time: 106.814
# Episode: 85 Exploration P: 0.1243 Total reward: -546.7523218707657 SOC: 0.1670 Cumulative_SOC_deviation: 455.2341 Fuel Consumption: 91.5182
#
# maximum steps, simulation is done ...
# elapsed_time: 108.373
# Episode: 86 Exploration P: 0.1212 Total reward: -578.4234347421018 SOC: 0.0451 Cumulative_SOC_deviation: 495.9044 Fuel Consumption: 82.5191
#
# maximum steps, simulation is done ...
# elapsed_time: 107.795
# Episode: 87 Exploration P: 0.1182 Total reward: -522.9331055909396 SOC: 0.0954 Cumulative_SOC_deviation: 437.3802 Fuel Consumption: 85.5529
#
# maximum steps, simulation is done ...
# elapsed_time: 108.702
# Episode: 88 Exploration P: 0.1153 Total reward: -477.5316247006604 SOC: 0.2694 Cumulative_SOC_deviation: 386.7746 Fuel Consumption: 90.7570
#
# maximum steps, simulation is done ...
# elapsed_time: 107.009
# Episode: 89 Exploration P: 0.1124 Total reward: -414.0982317268693 SOC: 0.3114 Cumulative_SOC_deviation: 322.3027 Fuel Consumption: 91.7956
#
# maximum steps, simulation is done ...
# elapsed_time: 106.997
# Episode: 90 Exploration P: 0.1096 Total reward: -479.1648129650904 SOC: 0.1383 Cumulative_SOC_deviation: 394.8843 Fuel Consumption: 84.2805
#
# maximum steps, simulation is done ...
# elapsed_time: 106.619
# Episode: 91 Exploration P: 0.1069 Total reward: -547.766083299445 SOC: 0.0319 Cumulative_SOC_deviation: 465.2010 Fuel Consumption: 82.5650
#
# battery power is 11936.939199203549(+) but condition is not avail
# elapsed_time: 54.513
# Episode: 92 Exploration P: 0.1056 Total reward: -1373.326831813613 SOC: -0.0003 Cumulative_SOC_deviation: 263.7052 Fuel Consumption: 110.2228
#
# maximum steps, simulation is done ...
# elapsed_time: 107.224
# Episode: 93 Exploration P: 0.1030 Total reward: -614.6945607158995 SOC: 0.1761 Cumulative_SOC_deviation: 525.0871 Fuel Consumption: 89.6074
#
# maximum steps, simulation is done ...
# elapsed_time: 107.697
# Episode: 94 Exploration P: 0.1005 Total reward: -579.5780995803032 SOC: 0.2326 Cumulative_SOC_deviation: 484.2206 Fuel Consumption: 95.3575
#
# maximum steps, simulation is done ...
# elapsed_time: 107.654
# Episode: 95 Exploration P: 0.0980 Total reward: -516.3283072445058 SOC: 0.2042 Cumulative_SOC_deviation: 430.2948 Fuel Consumption: 86.0335
#
# maximum steps, simulation is done ...
# elapsed_time: 106.666
# Episode: 96 Exploration P: 0.0956 Total reward: -522.2177093462699 SOC: 0.2141 Cumulative_SOC_deviation: 434.5657 Fuel Consumption: 87.6520
#
# maximum steps, simulation is done ...
# elapsed_time: 106.911
# Episode: 97 Exploration P: 0.0933 Total reward: -645.7606036235477 SOC: 0.1383 Cumulative_SOC_deviation: 561.1010 Fuel Consumption: 84.6596
# maximum steps, simulation is done ...
# elapsed_time: 106.764
# Episode: 98 Exploration P: 0.0911 Total reward: -508.49370616348045 SOC: 0.1829 Cumulative_SOC_deviation: 424.5609 Fuel Consumption: 83.9328
#
# maximum steps, simulation is done ...
# elapsed_time: 107.010
# Episode: 99 Exploration P: 0.0889 Total reward: -561.1405204879708 SOC: 0.0852 Cumulative_SOC_deviation: 483.7018 Fuel Consumption: 77.4387
#
# maximum steps, simulation is done ...
# elapsed_time: 107.162
# Episode: 100 Exploration P: 0.0867 Total reward: -507.12102428212546 SOC: 0.1334 Cumulative_SOC_deviation: 425.5219 Fuel Consumption: 81.5991
#
# maximum steps, simulation is done ...
# elapsed_time: 109.152
# Episode: 101 Exploration P: 0.0847 Total reward: -689.3773937698656 SOC: 0.0816 Cumulative_SOC_deviation: 606.0542 Fuel Consumption: 83.3232
#
# maximum steps, simulation is done ...
# elapsed_time: 108.024
# Episode: 102 Exploration P: 0.0826 Total reward: -674.2066580488305 SOC: 0.0755 Cumulative_SOC_deviation: 585.3556 Fuel Consumption: 88.8511
#
# battery power is 8503.02714804438(+) but condition is not avail
# elapsed_time: 72.463
# Episode: 103 Exploration P: 0.0813 Total reward: -1481.5077813506518 SOC: -0.0001 Cumulative_SOC_deviation: 401.4172 Fuel Consumption: 80.6915
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 49.051
# Episode: 104 Exploration P: 0.0804 Total reward: -1270.2239473680306 SOC: -0.0000 Cumulative_SOC_deviation: 225.2696 Fuel Consumption: 45.5552
#
# battery power is 6202.561422165171(+) but condition is not avail
# elapsed_time: 51.203
# Episode: 105 Exploration P: 0.0795 Total reward: -1357.006237655652 SOC: -0.0005 Cumulative_SOC_deviation: 243.7557 Fuel Consumption: 113.9582
#
# battery power is 6311.492138965655(+) but condition is not avail
# elapsed_time: 47.368
# Episode: 106 Exploration P: 0.0787 Total reward: -1252.7010279500346 SOC: -0.0016 Cumulative_SOC_deviation: 222.5879 Fuel Consumption: 30.8083
#
# battery power is 10943.72603046869(+) but condition is not avail
# elapsed_time: 46.463
# Episode: 107 Exploration P: 0.0778 Total reward: -1284.1050104983774 SOC: -0.0014 Cumulative_SOC_deviation: 215.4029 Fuel Consumption: 69.3043
#
# battery power is 1901.9537648096489(+) but condition is not avail
# elapsed_time: 71.339
# Episode: 108 Exploration P: 0.0766 Total reward: -1495.1633780238997 SOC: -0.0011 Cumulative_SOC_deviation: 404.4049 Fuel Consumption: 91.3605
#
# battery power is 19821.500130024076(+) but condition is not avail
# elapsed_time: 91.068
# Episode: 109 Exploration P: 0.0751 Total reward: -1651.0044453483288 SOC: -0.0002 Cumulative_SOC_deviation: 548.6759 Fuel Consumption: 102.9297
#
# battery power is 12769.926186790764(+) but condition is not avail
# elapsed_time: 86.252
# Episode: 110 Exploration P: 0.0736 Total reward: -1705.3432756775621 SOC: -0.0006 Cumulative_SOC_deviation: 508.0476 Fuel Consumption: 197.8972
#
# battery power is 9851.64969299313(+) but condition is not avail
# elapsed_time: 100.553
# Episode: 111 Exploration P: 0.0720 Total reward: -1736.9322603932246 SOC: -0.0007 Cumulative_SOC_deviation: 600.1177 Fuel Consumption: 137.4161
#
# maximum steps, simulation is done ...
# elapsed_time: 107.387
# Episode: 112 Exploration P: 0.0703 Total reward: -887.9992061680133 SOC: -0.0002 Cumulative_SOC_deviation: 667.4715 Fuel Consumption: 220.5277
#
# battery power is 11357.441406241593(+) but condition is not avail
# elapsed_time: 61.430
# Episode: 113 Exploration P: 0.0694 Total reward: -1559.0527587249253 SOC: -0.0003 Cumulative_SOC_deviation: 330.0426 Fuel Consumption: 229.6113
#
# battery power is 3433.3666239437007(+) but condition is not avail
# elapsed_time: 68.717
# Episode: 114 Exploration P: 0.0684 Total reward: -1457.9609980571797 SOC: -0.0000 Cumulative_SOC_deviation: 383.8422 Fuel Consumption: 74.8124
#
# battery power is 12617.487566805248(+) but condition is not avail
# elapsed_time: 75.920
# Episode: 115 Exploration P: 0.0672 Total reward: -1589.3105538616423 SOC: -0.0007 Cumulative_SOC_deviation: 431.9940 Fuel Consumption: 157.9180
#
# battery power is 8895.534323273678(+) but condition is not avail
# elapsed_time: 82.963
# Episode: 116 Exploration P: 0.0660 Total reward: -1561.583640021579 SOC: -0.0001 Cumulative_SOC_deviation: 469.8501 Fuel Consumption: 92.4273
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 49.988
# Episode: 117 Exploration P: 0.0653 Total reward: -1377.6501396576637 SOC: -0.0002 Cumulative_SOC_deviation: 243.9964 Fuel Consumption: 134.2548
#
# battery power is 11357.441406241593(+) but condition is not avail
# elapsed_time: 60.849
# Episode: 118 Exploration P: 0.0645 Total reward: -1501.0464042872438 SOC: -0.0003 Cumulative_SOC_deviation: 326.5187 Fuel Consumption: 175.1289
#
# battery power is 9399.485516747744(+) but condition is not avail
# elapsed_time: 37.343
# Episode: 119 Exploration P: 0.0640 Total reward: -1166.8392323735852 SOC: -0.0002 Cumulative_SOC_deviation: 150.6224 Fuel Consumption: 16.8179
#
# battery power is 6526.981902015126(+) but condition is not avail
# elapsed_time: 45.116
# Episode: 120 Exploration P: 0.0633 Total reward: -1223.70184683143 SOC: -0.0001 Cumulative_SOC_deviation: 198.1432 Fuel Consumption: 26.1596
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 106.616
# Episode: 121 Exploration P: 0.0619 Total reward: -2133.999562329792 SOC: -0.0003 Cumulative_SOC_deviation: 663.0310 Fuel Consumption: 471.5697
#
# battery power is 6311.492138965655(+) but condition is not avail
# elapsed_time: 47.470
# Episode: 122 Exploration P: 0.0613 Total reward: -1257.4642722610542 SOC: -0.0003 Cumulative_SOC_deviation: 223.0227 Fuel Consumption: 35.1354
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 102.362
# Episode: 123 Exploration P: 0.0599 Total reward: -1825.1894633093857 SOC: -0.0006 Cumulative_SOC_deviation: 637.3834 Fuel Consumption: 188.4075
#
# battery power is 4687.049915800661(+) but condition is not avail
# elapsed_time: 60.334
# Episode: 124 Exploration P: 0.0592 Total reward: -1448.8515378040302 SOC: -0.0004 Cumulative_SOC_deviation: 329.9325 Fuel Consumption: 119.6131
#
# battery power is 857.6657444176781(+) but condition is not avail
# elapsed_time: 65.563
# Episode: 125 Exploration P: 0.0583 Total reward: -1604.8590125618402 SOC: -0.0003 Cumulative_SOC_deviation: 366.9373 Fuel Consumption: 238.6156
#
# battery power is 2263.5076869801633(+) but condition is not avail
# elapsed_time: 44.714
# Episode: 126 Exploration P: 0.0578 Total reward: -1254.3210789100056 SOC: -0.0007 Cumulative_SOC_deviation: 206.9070 Fuel Consumption: 48.1084
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 43.709
# Episode: 127 Exploration P: 0.0573 Total reward: -1236.5095443399896 SOC: -0.0014 Cumulative_SOC_deviation: 195.7050 Fuel Consumption: 41.4068
#
# battery power is 8370.966351628711(+) but condition is not avail
# elapsed_time: 100.872
# Episode: 128 Exploration P: 0.0560 Total reward: -1966.0550721673935 SOC: -0.0005 Cumulative_SOC_deviation: 624.0414 Fuel Consumption: 342.6150
#
# battery power is 14823.669712558756(+) but condition is not avail
# elapsed_time: 75.919
# Episode: 129 Exploration P: 0.0552 Total reward: -1526.3599272725116 SOC: -0.0006 Cumulative_SOC_deviation: 424.2952 Fuel Consumption: 102.6662
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 54.635
# Episode: 130 Exploration P: 0.0545 Total reward: -1437.762279506926 SOC: -0.0003 Cumulative_SOC_deviation: 280.2883 Fuel Consumption: 158.0751
#
# battery power is 7004.315577931076(+) but condition is not avail
# elapsed_time: 64.218
# Episode: 131 Exploration P: 0.0538 Total reward: -1563.1455351773914 SOC: -0.0000 Cumulative_SOC_deviation: 353.4832 Fuel Consumption: 210.2631
#
# battery power is 4550.368240543639(+) but condition is not avail
# elapsed_time: 85.147
# Episode: 132 Exploration P: 0.0529 Total reward: -1598.5763327345549 SOC: -0.0007 Cumulative_SOC_deviation: 496.9826 Fuel Consumption: 102.1953
#
# battery power is 5835.930017910628(+) but condition is not avail
# elapsed_time: 57.260
# Episode: 133 Exploration P: 0.0522 Total reward: -1338.0933669204564 SOC: -0.0001 Cumulative_SOC_deviation: 279.7725 Fuel Consumption: 59.0145
#
# battery power is 5739.574016283987(+) but condition is not avail
# elapsed_time: 69.089
# Episode: 134 Exploration P: 0.0515 Total reward: -1546.7690878474993 SOC: -0.0006 Cumulative_SOC_deviation: 383.4367 Fuel Consumption: 163.9338
# battery power is 663.7725566044937(+) but condition is not avail
# elapsed_time: 100.902
# Episode: 135 Exploration P: 0.0504 Total reward: -1951.698890698868 SOC: -0.0002 Cumulative_SOC_deviation: 615.1885 Fuel Consumption: 337.2041
#
# battery power is 773.9037145420134(+) but condition is not avail
# elapsed_time: 55.127
# Episode: 136 Exploration P: 0.0499 Total reward: -1387.5342577606707 SOC: -0.0009 Cumulative_SOC_deviation: 278.1432 Fuel Consumption: 110.0855
#
# battery power is 651.8567835680633(+) but condition is not avail
# elapsed_time: 48.144
# Episode: 137 Exploration P: 0.0494 Total reward: -1268.9753464297708 SOC: -0.0003 Cumulative_SOC_deviation: 229.2923 Fuel Consumption: 40.2841
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 81.540
# Episode: 138 Exploration P: 0.0486 Total reward: -1520.4546644039779 SOC: -0.0005 Cumulative_SOC_deviation: 455.7570 Fuel Consumption: 65.2990
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 96.872
# Episode: 139 Exploration P: 0.0476 Total reward: -1714.8810225329137 SOC: -0.0004 Cumulative_SOC_deviation: 563.1204 Fuel Consumption: 152.3618
#
# battery power is 559.3573539551726(+) but condition is not avail
# elapsed_time: 71.740
# Episode: 140 Exploration P: 0.0469 Total reward: -1658.245566504456 SOC: -0.0003 Cumulative_SOC_deviation: 413.4989 Fuel Consumption: 245.4406
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 50.015
# Episode: 141 Exploration P: 0.0465 Total reward: -1310.6741678582127 SOC: -0.0003 Cumulative_SOC_deviation: 236.5227 Fuel Consumption: 74.7526
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 103.396
# Episode: 142 Exploration P: 0.0455 Total reward: -1786.944166755828 SOC: -0.0003 Cumulative_SOC_deviation: 635.7533 Fuel Consumption: 151.7921
#
# battery power is 9432.2911721516(+) but condition is not avail
# elapsed_time: 63.313
# Episode: 143 Exploration P: 0.0450 Total reward: -1550.3238623223394 SOC: -0.0005 Cumulative_SOC_deviation: 335.2996 Fuel Consumption: 215.7209
#
# battery power is 8503.02714804438(+) but condition is not avail
# elapsed_time: 72.690
# Episode: 144 Exploration P: 0.0443 Total reward: -1521.9025968139088 SOC: -0.0001 Cumulative_SOC_deviation: 403.3966 Fuel Consumption: 119.1070
#
# battery power is 12021.138112619446(+) but condition is not avail
# elapsed_time: 51.526
# Episode: 145 Exploration P: 0.0439 Total reward: -1408.5645871747138 SOC: -0.0009 Cumulative_SOC_deviation: 256.8079 Fuel Consumption: 152.3584
#
# battery power is 10886.199985334762(+) but condition is not avail
# elapsed_time: 78.863
# Episode: 146 Exploration P: 0.0432 Total reward: -1508.3001314253015 SOC: -0.0004 Cumulative_SOC_deviation: 448.8326 Fuel Consumption: 60.0687
#
# battery power is 6187.682709668528(+) but condition is not avail
# elapsed_time: 54.291
# Episode: 147 Exploration P: 0.0427 Total reward: -1464.9515867706423 SOC: -0.0009 Cumulative_SOC_deviation: 284.7786 Fuel Consumption: 180.7747
#
# battery power is 1825.1499874711299(+) but condition is not avail
# elapsed_time: 91.579
# Episode: 148 Exploration P: 0.0420 Total reward: -1670.2737624361953 SOC: -0.0000 Cumulative_SOC_deviation: 554.7410 Fuel Consumption: 116.3191
#
# maximum steps, simulation is done ...
# elapsed_time: 107.181
# Episode: 149 Exploration P: 0.0411 Total reward: -645.4031908319673 SOC: 0.0916 Cumulative_SOC_deviation: 554.9920 Fuel Consumption: 90.4112
#
# battery power is 238.6206235536829(+) but condition is not avail
# elapsed_time: 48.487
# Episode: 150 Exploration P: 0.0407 Total reward: -1291.1786009301097 SOC: -0.0007 Cumulative_SOC_deviation: 234.9541 Fuel Consumption: 56.8300
#
# maximum steps, simulation is done ...
# elapsed_time: 107.612
# Episode: 151 Exploration P: 0.0399 Total reward: -575.932417924358 SOC: 0.1453 Cumulative_SOC_deviation: 482.1431 Fuel Consumption: 93.7893
#
# maximum steps, simulation is done ...
# elapsed_time: 108.242
# Episode: 152 Exploration P: 0.0391 Total reward: -656.4613484652048 SOC: 0.1056 Cumulative_SOC_deviation: 565.5559 Fuel Consumption: 90.9055
#
# maximum steps, simulation is done ...
# elapsed_time: 107.235
# Episode: 153 Exploration P: 0.0383 Total reward: -659.61653611913 SOC: 0.0342 Cumulative_SOC_deviation: 577.5587 Fuel Consumption: 82.0578
#
# maximum steps, simulation is done ...
# elapsed_time: 107.644
# Episode: 154 Exploration P: 0.0375 Total reward: -737.0579718271528 SOC: 0.0950 Cumulative_SOC_deviation: 648.9592 Fuel Consumption: 88.0987
#
# maximum steps, simulation is done ...
# elapsed_time: 106.842
# Episode: 155 Exploration P: 0.0368 Total reward: -703.8471895803815 SOC: 0.0517 Cumulative_SOC_deviation: 622.4589 Fuel Consumption: 81.3883
#
# battery power is 10240.20840098544(+) but condition is not avail
# elapsed_time: 91.744
# Episode: 156 Exploration P: 0.0362 Total reward: -1750.4791924884291 SOC: -0.0005 Cumulative_SOC_deviation: 543.7320 Fuel Consumption: 207.4616
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 80.574
# Episode: 157 Exploration P: 0.0356 Total reward: -1773.9211406580507 SOC: -0.0011 Cumulative_SOC_deviation: 475.3277 Fuel Consumption: 299.1954
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 48.681
# Episode: 158 Exploration P: 0.0353 Total reward: -1384.138855352134 SOC: -0.0006 Cumulative_SOC_deviation: 240.9318 Fuel Consumption: 143.8085
#
# battery power is 9399.485516747744(+) but condition is not avail
# elapsed_time: 37.770
# Episode: 159 Exploration P: 0.0351 Total reward: -1179.1670247464526 SOC: -0.0002 Cumulative_SOC_deviation: 157.3112 Fuel Consumption: 22.4568
#
# maximum steps, simulation is done ...
# elapsed_time: 107.872
# Episode: 160 Exploration P: 0.0344 Total reward: -726.4271041436314 SOC: 0.0102 Cumulative_SOC_deviation: 642.2372 Fuel Consumption: 84.1899
#
# battery power is 12822.307316824854(+) but condition is not avail
# elapsed_time: 94.608
# Episode: 161 Exploration P: 0.0338 Total reward: -1661.450921146543 SOC: -0.0005 Cumulative_SOC_deviation: 566.5666 Fuel Consumption: 95.4857
#
# maximum steps, simulation is done ...
# elapsed_time: 108.132
# Episode: 162 Exploration P: 0.0332 Total reward: -1002.2795976376639 SOC: -0.0000 Cumulative_SOC_deviation: 679.0186 Fuel Consumption: 323.2610
#
# maximum steps, simulation is done ...
# elapsed_time: 107.124
# Episode: 163 Exploration P: 0.0325 Total reward: -739.0469837685257 SOC: 0.0076 Cumulative_SOC_deviation: 658.5108 Fuel Consumption: 80.5362
#
# maximum steps, simulation is done ...
# elapsed_time: 107.484
# Episode: 164 Exploration P: 0.0319 Total reward: -757.5546317149635 SOC: 0.0079 Cumulative_SOC_deviation: 678.3947 Fuel Consumption: 79.1599
#
# battery power is 608.6368386759896(+) but condition is not avail
# elapsed_time: 51.298
# Episode: 165 Exploration P: 0.0316 Total reward: -1359.953660444711 SOC: -0.0002 Cumulative_SOC_deviation: 262.0408 Fuel Consumption: 98.6067
#
# battery power is 14227.237629884365(+) but condition is not avail
# elapsed_time: 44.727
# Episode: 166 Exploration P: 0.0314 Total reward: -1307.0055595744686 SOC: -0.0020 Cumulative_SOC_deviation: 210.5860 Fuel Consumption: 97.0224
#
# battery power is 1601.7716185726358(+) but condition is not avail
# elapsed_time: 93.457
# Episode: 167 Exploration P: 0.0309 Total reward: -1756.7741250840936 SOC: -0.0007 Cumulative_SOC_deviation: 568.7079 Fuel Consumption: 188.7606
#
# maximum steps, simulation is done ...
# elapsed_time: 106.753
# Episode: 168 Exploration P: 0.0303 Total reward: -1311.5086245161926 SOC: -0.0002 Cumulative_SOC_deviation: 685.2859 Fuel Consumption: 626.2227
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 49.280
# Episode: 169 Exploration P: 0.0301 Total reward: -1369.8288221956677 SOC: -0.0013 Cumulative_SOC_deviation: 243.9014 Fuel Consumption: 126.5296
#
# battery power is 2410.5704499215344(+) but condition is not avail
# elapsed_time: 99.446
# Episode: 170 Exploration P: 0.0296 Total reward: -1688.0740082073098 SOC: -0.0007 Cumulative_SOC_deviation: 593.7298 Fuel Consumption: 95.0385
#
# battery power is 6496.348111152887(+) but condition is not avail
# elapsed_time: 67.655
# Episode: 171 Exploration P: 0.0292 Total reward: -1584.529730137981 SOC: -0.0005 Cumulative_SOC_deviation: 378.1014 Fuel Consumption: 207.0297
# battery power is 4455.100664393433(+) but condition is not avail
# elapsed_time: 63.054
# Episode: 172 Exploration P: 0.0289 Total reward: -1511.7114890742714 SOC: -0.0001 Cumulative_SOC_deviation: 342.2331 Fuel Consumption: 170.1720
#
# battery power is 8639.66101848357(+) but condition is not avail
# elapsed_time: 101.891
# Episode: 173 Exploration P: 0.0284 Total reward: -1838.994373717253 SOC: -0.0006 Cumulative_SOC_deviation: 584.7270 Fuel Consumption: 254.8687
#
# maximum steps, simulation is done ...
# elapsed_time: 107.585
# Episode: 174 Exploration P: 0.0279 Total reward: -679.047454772292 SOC: 0.0207 Cumulative_SOC_deviation: 595.1194 Fuel Consumption: 83.9280
#
# battery power is 9344.08275176345(+) but condition is not avail
# elapsed_time: 88.896
# Episode: 175 Exploration P: 0.0275 Total reward: -1994.926126939591 SOC: -0.0013 Cumulative_SOC_deviation: 540.9212 Fuel Consumption: 454.6071
#
# maximum steps, simulation is done ...
# elapsed_time: 107.096
# Episode: 176 Exploration P: 0.0271 Total reward: -684.0885842405893 SOC: 0.0265 Cumulative_SOC_deviation: 598.9753 Fuel Consumption: 85.1133
#
# maximum steps, simulation is done ...
# elapsed_time: 106.937
# Episode: 177 Exploration P: 0.0266 Total reward: -1244.0537829658226 SOC: -0.0007 Cumulative_SOC_deviation: 686.6291 Fuel Consumption: 557.4247
#
# battery power is 6195.756978263763(+) but condition is not avail
# elapsed_time: 70.769
# Episode: 178 Exploration P: 0.0263 Total reward: -1504.1966450381813 SOC: -0.0007 Cumulative_SOC_deviation: 401.8744 Fuel Consumption: 102.9238
#
# maximum steps, simulation is done ...
# elapsed_time: 106.630
# Episode: 179 Exploration P: 0.0259 Total reward: -735.4351879582686 SOC: 0.0540 Cumulative_SOC_deviation: 655.5699 Fuel Consumption: 79.8653
#
# maximum steps, simulation is done ...
# elapsed_time: 107.103
# Episode: 180 Exploration P: 0.0254 Total reward: -732.3356173520486 SOC: 0.0653 Cumulative_SOC_deviation: 651.5523 Fuel Consumption: 80.7833
#
# maximum steps, simulation is done ...
# elapsed_time: 107.048
# Episode: 181 Exploration P: 0.0250 Total reward: -703.5128033541243 SOC: 0.1842 Cumulative_SOC_deviation: 611.5579 Fuel Consumption: 91.9549
#
# battery power is 3103.092223832466(+) but condition is not avail
# elapsed_time: 79.173
# Episode: 182 Exploration P: 0.0247 Total reward: -1605.4704977817087 SOC: -0.0003 Cumulative_SOC_deviation: 432.7299 Fuel Consumption: 173.3417
#
# maximum steps, simulation is done ...
# elapsed_time: 107.526
# Episode: 183 Exploration P: 0.0243 Total reward: -745.4448099976709 SOC: 0.0428 Cumulative_SOC_deviation: 663.2466 Fuel Consumption: 82.1982
#
# battery power is 18029.546737505574(+) but condition is not avail
# elapsed_time: 91.840
# Episode: 184 Exploration P: 0.0240 Total reward: -1800.5431255200215 SOC: -0.0010 Cumulative_SOC_deviation: 547.9861 Fuel Consumption: 253.1920
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 39.815
# Episode: 185 Exploration P: 0.0238 Total reward: -1211.5904399072365 SOC: -0.0002 Cumulative_SOC_deviation: 173.6194 Fuel Consumption: 38.5720
#
# battery power is 4224.368500484229(+) but condition is not avail
# elapsed_time: 106.121
# Episode: 186 Exploration P: 0.0235 Total reward: -1750.151873618097 SOC: -0.0007 Cumulative_SOC_deviation: 608.5698 Fuel Consumption: 142.2764
#
# maximum steps, simulation is done ...
# elapsed_time: 114.929
# Episode: 187 Exploration P: 0.0231 Total reward: -673.6800465669287 SOC: 0.1098 Cumulative_SOC_deviation: 580.1777 Fuel Consumption: 93.5024
#
# maximum steps, simulation is done ...
# elapsed_time: 109.566
# Episode: 188 Exploration P: 0.0227 Total reward: -650.1973870732522 SOC: 0.0834 Cumulative_SOC_deviation: 559.0010 Fuel Consumption: 91.1964
#
# maximum steps, simulation is done ...
# elapsed_time: 111.400
# Episode: 189 Exploration P: 0.0224 Total reward: -699.9878688701697 SOC: 0.0791 Cumulative_SOC_deviation: 611.9191 Fuel Consumption: 88.0688
#
# battery power is 107.67193171428607(+) but condition is not avail
# elapsed_time: 79.443
# Episode: 190 Exploration P: 0.0222 Total reward: -1499.924540429385 SOC: -0.0001 Cumulative_SOC_deviation: 401.6532 Fuel Consumption: 98.8762
#
# maximum steps, simulation is done ...
# elapsed_time: 119.704
# Episode: 191 Exploration P: 0.0218 Total reward: -716.0320867736067 SOC: 0.0566 Cumulative_SOC_deviation: 633.2813 Fuel Consumption: 82.7508
#
# maximum steps, simulation is done ...
# elapsed_time: 108.674
# Episode: 192 Exploration P: 0.0215 Total reward: -728.0514326312054 SOC: 0.0691 Cumulative_SOC_deviation: 646.1083 Fuel Consumption: 81.9432
#
# maximum steps, simulation is done ...
# elapsed_time: 119.502
# Episode: 193 Exploration P: 0.0212 Total reward: -629.7017768046579 SOC: 0.1365 Cumulative_SOC_deviation: 540.8416 Fuel Consumption: 88.8602
#
# maximum steps, simulation is done ...
# elapsed_time: 114.414
# Episode: 194 Exploration P: 0.0209 Total reward: -677.1170376211275 SOC: 0.0807 Cumulative_SOC_deviation: 589.0745 Fuel Consumption: 88.0425
#
# battery power is 2263.5076869801633(+) but condition is not avail
# elapsed_time: 49.806
# Episode: 195 Exploration P: 0.0208 Total reward: -1239.0280808046969 SOC: -0.0003 Cumulative_SOC_deviation: 211.9768 Fuel Consumption: 27.7452
#
# battery power is 4311.852766275703(+) but condition is not avail
# elapsed_time: 53.841
# Episode: 196 Exploration P: 0.0206 Total reward: -1341.7774872605607 SOC: -0.0003 Cumulative_SOC_deviation: 253.3330 Fuel Consumption: 89.1385
#
# maximum steps, simulation is done ...
# elapsed_time: 117.401
# Episode: 197 Exploration P: 0.0204 Total reward: -689.2485632500069 SOC: 0.0457 Cumulative_SOC_deviation: 602.8850 Fuel Consumption: 86.3636
#
# maximum steps, simulation is done ...
# elapsed_time: 102.244
# Episode: 198 Exploration P: 0.0201 Total reward: -748.2309890195824 SOC: 0.0171 Cumulative_SOC_deviation: 662.4668 Fuel Consumption: 85.7642
#
# maximum steps, simulation is done ...
# elapsed_time: 82.834
# Episode: 199 Exploration P: 0.0198 Total reward: -737.5051741917086 SOC: 0.0364 Cumulative_SOC_deviation: 651.7351 Fuel Consumption: 85.7701
#
# maximum steps, simulation is done ...
# elapsed_time: 80.325
# Episode: 200 Exploration P: 0.0195 Total reward: -653.185425422628 SOC: 0.1227 Cumulative_SOC_deviation: 563.7982 Fuel Consumption: 89.3872
#
# model is saved..
#
# Trial 2
#
# maximum steps, simulation is done ...
# elapsed_time: 13.334
# Episode: 1 Exploration P: 1.0000 Total reward: -1151.6319263080268 SOC: 1.0000 Cumulative_SOC_deviation: 482.6255 Fuel Consumption: 186.3809
#
# maximum steps, simulation is done ...
# elapsed_time: 12.673
# Episode: 2 Exploration P: 1.0000 Total reward: -1137.179658166884 SOC: 1.0000 Cumulative_SOC_deviation: 472.4771 Fuel Consumption: 192.2255
#
# maximum steps, simulation is done ...
# elapsed_time: 12.778
# Episode: 3 Exploration P: 1.0000 Total reward: -1155.763104235261 SOC: 0.9993 Cumulative_SOC_deviation: 482.0832 Fuel Consumption: 191.5967
#
# WARNING:tensorflow:Layer batch_normalization_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer batch_normalization_7 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# ...
#
# battery power is 7077.883302991055(+) but condition is not avail
# elapsed_time: 70.014
# Episode: 125 Exploration P: 0.0597 Total reward: -2457.3444621964454 SOC: -0.0009 Cumulative_SOC_deviation: 444.6334 Fuel Consumption: 125.2481
#
# maximum steps, simulation is done ...
# elapsed_time: 84.559
# Episode: 126 Exploration P: 0.0584 Total reward: -1725.082363727585 SOC: 0.0023 Cumulative_SOC_deviation: 550.3175 Fuel Consumption: 74.1299
#
# battery power is 7445.580173137729(+) but condition is not avail
# elapsed_time: 48.563
# Episode: 127 Exploration P: 0.0576 Total reward: -2141.702845942482 SOC: -0.0004 Cumulative_SOC_deviation: 323.9676 Fuel Consumption: 171.6020
#
# battery power is 11198.937655106349(+) but condition is not avail
# elapsed_time: 54.741
# Episode: 128 Exploration P: 0.0568 Total reward: -2001.6240448631406 SOC: -0.0001 Cumulative_SOC_deviation: 319.6117 Fuel Consumption: 44.5902
#
# battery power is 4332.921690006763(+) but condition is not avail
# elapsed_time: 62.200
# Episode: 129 Exploration P: 0.0559 Total reward: -2697.473124953854 SOC: -0.0006 Cumulative_SOC_deviation: 451.6333 Fuel Consumption: 344.3757
#
# maximum steps, simulation is done ...
# elapsed_time: 84.508
# Episode: 130 Exploration P: 0.0546 Total reward: -1847.0258343186072 SOC: 0.1270 Cumulative_SOC_deviation: 584.6291 Fuel Consumption: 93.1384
#
# maximum steps, simulation is done ...
# elapsed_time: 84.919
# Episode: 131 Exploration P: 0.0534 Total reward: -1711.610053484379 SOC: 0.1620 Cumulative_SOC_deviation: 541.4100 Fuel Consumption: 87.3801
#
# maximum steps, simulation is done ...
# elapsed_time: 84.909
# Episode: 132 Exploration P: 0.0522 Total reward: -1690.689244216602 SOC: 0.2127 Cumulative_SOC_deviation: 530.4802 Fuel Consumption: 99.2488
#
# battery power is 5204.826318047967(+) but condition is not avail
# elapsed_time: 40.585
# Episode: 133 Exploration P: 0.0517 Total reward: -1731.8821694467756 SOC: -0.0013 Cumulative_SOC_deviation: 233.7667 Fuel Consumption: 32.4798
#
# battery power is 7602.922534362306(+) but condition is not avail
# elapsed_time: 49.434
# Episode: 134 Exploration P: 0.0510 Total reward: -2048.1771816858336 SOC: -0.0020 Cumulative_SOC_deviation: 327.8638 Fuel Consumption: 66.3925
#
# maximum steps, simulation is done ...
# elapsed_time: 85.104
# Episode: 135 Exploration P: 0.0499 Total reward: -1318.3025984943586 SOC: 0.1118 Cumulative_SOC_deviation: 411.4318 Fuel Consumption: 84.0072
# maximum steps, simulation is done ...
# elapsed_time: 85.091
# Episode: 136 Exploration P: 0.0488 Total reward: -1750.0215604879945 SOC: 0.2003 Cumulative_SOC_deviation: 551.7881 Fuel Consumption: 94.6574
#
# maximum steps, simulation is done ...
# elapsed_time: 85.088
# Episode: 137 Exploration P: 0.0478 Total reward: -1154.1286350623254 SOC: 0.1934 Cumulative_SOC_deviation: 355.6129 Fuel Consumption: 87.2899
#
# maximum steps, simulation is done ...
# elapsed_time: 84.466
# Episode: 138 Exploration P: 0.0468 Total reward: -1217.0541835653262 SOC: 0.3509 Cumulative_SOC_deviation: 372.7651 Fuel Consumption: 98.7590
#
# maximum steps, simulation is done ...
# elapsed_time: 84.326
# Episode: 139 Exploration P: 0.0458 Total reward: -894.2997956627557 SOC: 0.4041 Cumulative_SOC_deviation: 264.7323 Fuel Consumption: 100.1030
#
# maximum steps, simulation is done ...
# elapsed_time: 84.362
# Episode: 140 Exploration P: 0.0448 Total reward: -861.7396369459348 SOC: 0.3704 Cumulative_SOC_deviation: 254.7663 Fuel Consumption: 97.4406
#
# maximum steps, simulation is done ...
# elapsed_time: 84.254
# Episode: 141 Exploration P: 0.0438 Total reward: -914.665829483338 SOC: 0.3145 Cumulative_SOC_deviation: 274.5233 Fuel Consumption: 91.0960
#
# maximum steps, simulation is done ...
# elapsed_time: 84.173
# Episode: 142 Exploration P: 0.0429 Total reward: -864.7094067757233 SOC: 0.4093 Cumulative_SOC_deviation: 253.8868 Fuel Consumption: 103.0491
#
# maximum steps, simulation is done ...
# elapsed_time: 84.177
# Episode: 143 Exploration P: 0.0420 Total reward: -1022.6881458670587 SOC: 0.3901 Cumulative_SOC_deviation: 307.7052 Fuel Consumption: 99.5725
#
# maximum steps, simulation is done ...
# elapsed_time: 84.367
# Episode: 144 Exploration P: 0.0412 Total reward: -1072.589389249588 SOC: 0.3220 Cumulative_SOC_deviation: 324.0887 Fuel Consumption: 100.3234
#
# maximum steps, simulation is done ...
# elapsed_time: 84.385
# Episode: 145 Exploration P: 0.0403 Total reward: -1122.1343859673214 SOC: 0.3316 Cumulative_SOC_deviation: 341.9943 Fuel Consumption: 96.1514
#
# maximum steps, simulation is done ...
# elapsed_time: 84.314
# Episode: 146 Exploration P: 0.0395 Total reward: -997.9409920241429 SOC: 0.2971 Cumulative_SOC_deviation: 302.1789 Fuel Consumption: 91.4043
#
# maximum steps, simulation is done ...
# elapsed_time: 84.444
# Episode: 147 Exploration P: 0.0387 Total reward: -1185.4086193048681 SOC: 0.4339 Cumulative_SOC_deviation: 359.4378 Fuel Consumption: 107.0952
#
# maximum steps, simulation is done ...
# elapsed_time: 84.289
# Episode: 148 Exploration P: 0.0379 Total reward: -729.0512809686484 SOC: 0.4824 Cumulative_SOC_deviation: 204.5700 Fuel Consumption: 115.3411
#
# maximum steps, simulation is done ...
# elapsed_time: 84.563
# Episode: 149 Exploration P: 0.0372 Total reward: -717.974008724732 SOC: 0.5136 Cumulative_SOC_deviation: 201.4500 Fuel Consumption: 113.6241
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 71.603
# Episode: 150 Exploration P: 0.0365 Total reward: -2156.844627061964 SOC: -0.0006 Cumulative_SOC_deviation: 341.7097 Fuel Consumption: 133.5181
#
# battery power is 10977.001209334117(+) but condition is not avail
# elapsed_time: 28.833
# Episode: 151 Exploration P: 0.0363 Total reward: -1461.8430153891154 SOC: -0.0010 Cumulative_SOC_deviation: 148.8078 Fuel Consumption: 17.2235
#
# battery power is 12378.37205723446(+) but condition is not avail
# elapsed_time: 32.140
# Episode: 152 Exploration P: 0.0360 Total reward: -1612.9032116365452 SOC: -0.0008 Cumulative_SOC_deviation: 185.1018 Fuel Consumption: 59.4010
#
# battery power is 11117.403844718294(+) but condition is not avail
# elapsed_time: 65.482
# Episode: 153 Exploration P: 0.0355 Total reward: -3016.6981486306713 SOC: -0.0010 Cumulative_SOC_deviation: 508.9837 Fuel Consumption: 491.5509
#
# maximum steps, simulation is done ...
# elapsed_time: 84.122
# Episode: 154 Exploration P: 0.0348 Total reward: -1677.2571897682762 SOC: 0.0894 Cumulative_SOC_deviation: 529.7388 Fuel Consumption: 88.0407
#
# maximum steps, simulation is done ...
# elapsed_time: 84.741
# Episode: 155 Exploration P: 0.0341 Total reward: -1859.7923165759769 SOC: 0.0964 Cumulative_SOC_deviation: 589.1531 Fuel Consumption: 92.3330
#
# maximum steps, simulation is done ...
# elapsed_time: 85.099
# Episode: 156 Exploration P: 0.0335 Total reward: -1634.5194322891768 SOC: 0.0300 Cumulative_SOC_deviation: 517.2199 Fuel Consumption: 82.8597
#
# maximum steps, simulation is done ...
# elapsed_time: 84.693
# Episode: 157 Exploration P: 0.0328 Total reward: -1616.2553217977054 SOC: 0.4124 Cumulative_SOC_deviation: 503.6894 Fuel Consumption: 105.1871
#
# maximum steps, simulation is done ...
# elapsed_time: 84.937
# Episode: 158 Exploration P: 0.0322 Total reward: -1452.0775133094687 SOC: 0.2161 Cumulative_SOC_deviation: 454.5970 Fuel Consumption: 88.2864
#
# maximum steps, simulation is done ...
# elapsed_time: 84.819
# Episode: 159 Exploration P: 0.0316 Total reward: -1123.9586457367307 SOC: 0.1510 Cumulative_SOC_deviation: 346.7664 Fuel Consumption: 83.6593
#
# maximum steps, simulation is done ...
# elapsed_time: 84.575
# Episode: 160 Exploration P: 0.0310 Total reward: -1661.2167469786648 SOC: 0.2550 Cumulative_SOC_deviation: 521.7922 Fuel Consumption: 95.8403
#
# maximum steps, simulation is done ...
# elapsed_time: 84.575
# Episode: 161 Exploration P: 0.0304 Total reward: -1286.4659028324725 SOC: 0.2562 Cumulative_SOC_deviation: 397.8623 Fuel Consumption: 92.8790
#
# maximum steps, simulation is done ...
# elapsed_time: 84.585
# Episode: 162 Exploration P: 0.0299 Total reward: -1445.0599848245406 SOC: 0.2160 Cumulative_SOC_deviation: 452.4989 Fuel Consumption: 87.5633
#
# maximum steps, simulation is done ...
# elapsed_time: 84.840
# Episode: 163 Exploration P: 0.0294 Total reward: -1494.7794415900923 SOC: 0.1676 Cumulative_SOC_deviation: 469.3448 Fuel Consumption: 86.7451
#
# battery power is 6004.419133953151(+) but condition is not avail
# elapsed_time: 37.561
# Episode: 164 Exploration P: 0.0291 Total reward: -1716.664500653069 SOC: -0.0002 Cumulative_SOC_deviation: 226.5479 Fuel Consumption: 38.9149
#
# battery power is 7880.51494532994(+) but condition is not avail
# elapsed_time: 53.241
# Episode: 165 Exploration P: 0.0288 Total reward: -1914.4267302182957 SOC: -0.0010 Cumulative_SOC_deviation: 288.7089 Fuel Consumption: 50.1039
#
# maximum steps, simulation is done ...
# elapsed_time: 85.084
# Episode: 166 Exploration P: 0.0283 Total reward: -1828.2131703752154 SOC: 0.0553 Cumulative_SOC_deviation: 579.8797 Fuel Consumption: 88.5742
#
# battery power is 4151.405742548573(+) but condition is not avail
# elapsed_time: 50.588
# Episode: 167 Exploration P: 0.0280 Total reward: -2295.717660929889 SOC: -0.0001 Cumulative_SOC_deviation: 350.1748 Fuel Consumption: 246.9945
#
# battery power is 4556.04963138524(+) but condition is not avail
# elapsed_time: 42.837
# Episode: 168 Exploration P: 0.0277 Total reward: -1915.9315691431573 SOC: -0.0003 Cumulative_SOC_deviation: 270.1611 Fuel Consumption: 107.2501
#
# maximum steps, simulation is done ...
# elapsed_time: 85.178
# Episode: 169 Exploration P: 0.0273 Total reward: -2009.0923663687788 SOC: 0.0715 Cumulative_SOC_deviation: 641.1591 Fuel Consumption: 85.6151
#
# maximum steps, simulation is done ...
# elapsed_time: 84.791
# Episode: 170 Exploration P: 0.0268 Total reward: -1834.3770006005082 SOC: 0.1297 Cumulative_SOC_deviation: 581.2577 Fuel Consumption: 90.6039
#
# maximum steps, simulation is done ...
# elapsed_time: 84.814
# Episode: 171 Exploration P: 0.0263 Total reward: -1724.5520021726375 SOC: 0.1721 Cumulative_SOC_deviation: 543.4161 Fuel Consumption: 94.3036
#
# maximum steps, simulation is done ...
# elapsed_time: 84.735
# Episode: 172 Exploration P: 0.0259 Total reward: -1762.231702743065 SOC: 0.1605 Cumulative_SOC_deviation: 557.4067 Fuel Consumption: 90.0115
#
# maximum steps, simulation is done ...
# elapsed_time: 84.694
# Episode: 173 Exploration P: 0.0255 Total reward: -1516.0500890072562 SOC: 0.1558 Cumulative_SOC_deviation: 474.9010 Fuel Consumption: 91.3471
#
# maximum steps, simulation is done ...
# elapsed_time: 85.017
# Episode: 174 Exploration P: 0.0250 Total reward: -1138.2496460190634 SOC: 0.3646 Cumulative_SOC_deviation: 345.0121 Fuel Consumption: 103.2134
#
# maximum steps, simulation is done ...
# elapsed_time: 85.173
# Episode: 175 Exploration P: 0.0246 Total reward: -1054.0782405909104 SOC: 0.4183 Cumulative_SOC_deviation: 315.1794 Fuel Consumption: 108.5402
# maximum steps, simulation is done ...
# elapsed_time: 85.266
# Episode: 176 Exploration P: 0.0242 Total reward: -1019.3583632189956 SOC: 0.3774 Cumulative_SOC_deviation: 305.4539 Fuel Consumption: 102.9968
#
# maximum steps, simulation is done ...
# elapsed_time: 84.979
# Episode: 177 Exploration P: 0.0239 Total reward: -1461.0677624353839 SOC: 0.2679 Cumulative_SOC_deviation: 455.3662 Fuel Consumption: 94.9691
#
# maximum steps, simulation is done ...
# elapsed_time: 85.332
# Episode: 178 Exploration P: 0.0235 Total reward: -1231.9035820133827 SOC: 0.3457 Cumulative_SOC_deviation: 376.6801 Fuel Consumption: 101.8633
#
# maximum steps, simulation is done ...
# elapsed_time: 85.074
# Episode: 179 Exploration P: 0.0231 Total reward: -1213.110175225524 SOC: 0.2742 Cumulative_SOC_deviation: 374.2194 Fuel Consumption: 90.4520
#
# maximum steps, simulation is done ...
# elapsed_time: 85.223
# Episode: 180 Exploration P: 0.0228 Total reward: -923.2535899601295 SOC: 0.3998 Cumulative_SOC_deviation: 274.9729 Fuel Consumption: 98.3350
#
# maximum steps, simulation is done ...
# elapsed_time: 84.726
# Episode: 181 Exploration P: 0.0224 Total reward: -783.1840012775999 SOC: 0.4803 Cumulative_SOC_deviation: 227.4004 Fuel Consumption: 100.9827
#
# maximum steps, simulation is done ...
# elapsed_time: 85.202
# Episode: 182 Exploration P: 0.0221 Total reward: -555.8109310780221 SOC: 0.4362 Cumulative_SOC_deviation: 152.3214 Fuel Consumption: 98.8466
#
# maximum steps, simulation is done ...
# elapsed_time: 85.339
# Episode: 183 Exploration P: 0.0218 Total reward: -744.7393753318772 SOC: 0.4427 Cumulative_SOC_deviation: 213.8748 Fuel Consumption: 103.1150
#
# maximum steps, simulation is done ...
# elapsed_time: 84.950
# Episode: 184 Exploration P: 0.0214 Total reward: -1043.574309364203 SOC: 0.0609 Cumulative_SOC_deviation: 322.6179 Fuel Consumption: 75.7207
#
# battery power is 9642.042427194741(+) but condition is not avail
# elapsed_time: 28.836
# Episode: 185 Exploration P: 0.0213 Total reward: -1458.9687722443755 SOC: -0.0006 Cumulative_SOC_deviation: 149.0198 Fuel Consumption: 13.7121
#
# battery power is 3421.2001384046307(+) but condition is not avail
# elapsed_time: 60.370
# Episode: 186 Exploration P: 0.0211 Total reward: -2549.446607008221 SOC: -0.0004 Cumulative_SOC_deviation: 444.7021 Fuel Consumption: 217.2352
#
# battery power is 245.16322851542918(+) but condition is not avail
# elapsed_time: 76.780
# Episode: 187 Exploration P: 0.0208 Total reward: -2976.4917381391915 SOC: -0.0003 Cumulative_SOC_deviation: 561.2585 Fuel Consumption: 294.5249
#
# maximum steps, simulation is done ...
# elapsed_time: 85.153
# Episode: 188 Exploration P: 0.0205 Total reward: -1389.7723633686333 SOC: 0.3663 Cumulative_SOC_deviation: 431.3871 Fuel Consumption: 95.6111
#
# maximum steps, simulation is done ...
# elapsed_time: 85.077
# Episode: 189 Exploration P: 0.0203 Total reward: -939.3007042755492 SOC: 0.3971 Cumulative_SOC_deviation: 281.2826 Fuel Consumption: 95.4529
#
# maximum steps, simulation is done ...
# elapsed_time: 85.121
# Episode: 190 Exploration P: 0.0200 Total reward: -821.7035830329132 SOC: 0.4566 Cumulative_SOC_deviation: 240.6420 Fuel Consumption: 99.7775
#
# maximum steps, simulation is done ...
# elapsed_time: 85.196
# Episode: 191 Exploration P: 0.0197 Total reward: -889.2217242923231 SOC: 0.3776 Cumulative_SOC_deviation: 262.4862 Fuel Consumption: 101.7633
#
# maximum steps, simulation is done ...
# elapsed_time: 85.314
# Episode: 192 Exploration P: 0.0194 Total reward: -1096.823484100849 SOC: 0.3105 Cumulative_SOC_deviation: 335.1420 Fuel Consumption: 91.3976
#
# maximum steps, simulation is done ...
# elapsed_time: 84.973
# Episode: 193 Exploration P: 0.0192 Total reward: -1165.1296547934776 SOC: 0.2913 Cumulative_SOC_deviation: 358.9101 Fuel Consumption: 88.3993
#
# maximum steps, simulation is done ...
# elapsed_time: 85.123
# Episode: 194 Exploration P: 0.0189 Total reward: -1068.341518621954 SOC: 0.3543 Cumulative_SOC_deviation: 325.2595 Fuel Consumption: 92.5630
#
# maximum steps, simulation is done ...
# elapsed_time: 85.160
# Episode: 195 Exploration P: 0.0187 Total reward: -1013.4029325276134 SOC: 0.3748 Cumulative_SOC_deviation: 306.2505 Fuel Consumption: 94.6515
#
# maximum steps, simulation is done ...
# elapsed_time: 85.090
# Episode: 196 Exploration P: 0.0185 Total reward: -894.0334996709057 SOC: 0.3206 Cumulative_SOC_deviation: 267.9920 Fuel Consumption: 90.0575
#
# maximum steps, simulation is done ...
# elapsed_time: 85.044
# Episode: 197 Exploration P: 0.0182 Total reward: -982.277682864607 SOC: 0.5130 Cumulative_SOC_deviation: 291.0942 Fuel Consumption: 108.9951
#
# maximum steps, simulation is done ...
# elapsed_time: 84.771
# Episode: 198 Exploration P: 0.0180 Total reward: -473.72622432489567 SOC: 0.4448 Cumulative_SOC_deviation: 120.3856 Fuel Consumption: 112.5695
#
# maximum steps, simulation is done ...
# elapsed_time: 84.911
# Episode: 199 Exploration P: 0.0178 Total reward: -644.5389387415543 SOC: 0.4966 Cumulative_SOC_deviation: 178.1624 Fuel Consumption: 110.0518
#
# maximum steps, simulation is done ...
# elapsed_time: 84.656
# Episode: 200 Exploration P: 0.0176 Total reward: -472.4574362071224 SOC: 0.4865 Cumulative_SOC_deviation: 119.4289 Fuel Consumption: 114.1709
#
# model is saved..

# %%
with open("DDPG_cycleOne_1to3.pkl", "wb") as f: 
    pickle.dump(results_dict, f, pickle.HIGHEST_PROTOCOL)

# %%
# results_dict
